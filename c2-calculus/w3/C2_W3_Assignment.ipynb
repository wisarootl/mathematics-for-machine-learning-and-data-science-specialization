# %% [markdown]
# # Neural Network with Two Layers
#
# Welcome to your week three programming assignment. You are ready to build a neural network with two layers and train it to solve a classification problem.
#
# **After this assignment, you will be able to:**
#
# - Implement a neural network with two layers to a classification problem
# - Implement forward propagation using matrix multiplication
# - Perform backward propagation

# %% [markdown]
# # Table of Contents
#
# - [ 1 - Classification Problem](#1)
# - [ 2 - Neural Network Model with Two Layers](#2)
#   - [ 2.1 - Neural Network Model with Two Layers for a Single Training Example](#2.1)
#   - [ 2.2 - Neural Network Model with Two Layers for Multiple Training Examples](#2.2)
#   - [ 2.3 - Cost Function and Training](#2.3)
#   - [ 2.4 - Dataset](#2.4)
#   - [ 2.5 - Define Activation Function](#2.5)
#     - [ Exercise 1](#ex01)
# - [ 3 - Implementation of the Neural Network Model with Two Layers](#3)
#   - [ 3.1 - Defining the Neural Network Structure](#3.1)
#     - [ Exercise 2](#ex02)
#   - [ 3.2 - Initialize the Model's Parameters](#3.2)
#     - [ Exercise 3](#ex03)
#   - [ 3.3 - The Loop](#3.3)
#     - [ Exercise 4](#ex04)
#     - [ Exercise 5](#ex05)
#     - [ Exercise 6](#ex06)
#   - [ 3.4 - Integrate parts 3.1, 3.2 and 3.3 in nn_model()](#3.4)
#     - [ Exercise 7](#ex07)
#     - [ Exercise 8](#ex08)
# - [ 4 - Optional: Other Dataset](#4)

# %% [markdown]
# ## Packages
#
# First, import all the packages you will need during this assignment.

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import colors
# A function to create a dataset.
from sklearn.datasets import make_blobs

# Output of plotting commands is displayed inline within the Jupyter notebook.
# %matplotlib inline 

# Set a seed so that the results are consistent.
np.random.seed(3)

# %% [markdown]
# Load the unit tests defined for this notebook.

# %%
import w3_unittest

# %% [markdown]
# <a name='1'></a>
# ## 1 - Classification Problem

# %% [markdown]
# In one of the labs this week, you trained a neural network with a single perceptron, performing forward and backward propagation. That simple structure was enough to solve a "linear" classification problem - finding a straight line in a plane that would serve as a decision boundary to separate two classes.
#
# Imagine that now you have a more complicated problem: you still have two classes, but one line will not be enough to separate them.

# %%
fig, ax = plt.subplots()
xmin, xmax = -0.2, 1.4
x_line = np.arange(xmin, xmax, 0.1)
# Data points (observations) from two classes.
ax.scatter(0, 0, color="r")
ax.scatter(0, 1, color="b")
ax.scatter(1, 0, color="b")
ax.scatter(1, 1, color="r")
ax.set_xlim([xmin, xmax])
ax.set_ylim([-0.1, 1.1])
ax.set_xlabel('$x_1$')
ax.set_ylabel('$x_2$')
# Example of the lines which can be used as a decision boundary to separate two classes.
ax.plot(x_line, -1 * x_line + 1.5, color="black")
ax.plot(x_line, -1 * x_line + 0.5, color="black")
plt.plot()
# Out:
# []

# %% [markdown]
# This logic can appear in many applications. For example, if you train a model to predict whether you should buy a house knowing its size and the year it was built. A big new house will not be affordable, while a small old house will not be worth buying. So, you might be interested in either a big old house, or a small new house.
#
# The one perceptron neural network is not enough to solve such classification problem. Let's look at how you can adjust that model to find the solution.
#
# In the plot above, two lines can serve as a decision boundary. Your intuition might tell you that you should also increase the number of perceptrons. And that is absolutely right! You need to feed your data points (coordinates $x_1$, $x_2$) into two nodes separately and then unify them somehow with another one to make a decision.
#
# Now let's figure out the details, build and train your first multi-layer neural network!

# %% [markdown]
# <a name='2'></a>
# ## 2 - Neural Network Model with Two Layers

# %% [markdown]
# <a name='2.1'></a>
# ### 2.1 - Neural Network Model with Two Layers for a Single Training Example

# %% [markdown]
# <img src="images/nn_model_2_layers.png" style="width:1000px;">

# %% [markdown]
# The input and output layers of the neural network are the same as for one perceptron model, but there is a **hidden layer** now in between them. The training examples $x^{(i)}=\begin{bmatrix}x_1^{(i)} \\ x_2^{(i)}\end{bmatrix}$ from the input layer of size $n_x = 2$ are first fed into the hidden layer of size $n_h = 2$. They are simultaneously fed into the first perceptron with weights $W_1^{[1]}=\begin{bmatrix}w_{1,1}^{[1]} & w_{2,1}^{[1]}\end{bmatrix}$, bias  $b_1^{[1]}$; and into the second perceptron with weights $W_2^{[1]}=\begin{bmatrix}w_{1,2}^{[1]} & w_{2,2}^{[1]}\end{bmatrix}$, bias $b_2^{[1]}$. The integer in the square brackets $^{[1]}$ denotes the layer number, because there are two layers now with their own parameters and outputs, which need to be distinguished.
#
# \begin{align}
# z_1^{[1](i)} &= w_{1,1}^{[1]} x_1^{(i)} + w_{2,1}^{[1]} x_2^{(i)} + b_1^{[1]} = W_1^{[1]}x^{(i)} + b_1^{[1]},\\
# z_2^{[1](i)} &= w_{1,2}^{[1]} x_1^{(i)} + w_{2,2}^{[1]} x_2^{(i)} + b_2^{[1]} = W_2^{[1]}x^{(i)} + b_2^{[1]}.\tag{1}
# \end{align}
#
# These expressions for one training example $x^{(i)}$ can be rewritten in a matrix form :
#
# $$z^{[1](i)} = W^{[1]} x^{(i)} + b^{[1]},\tag{2}$$
#
# where
#
# &emsp; &emsp; $z^{[1](i)} = \begin{bmatrix}z_1^{[1](i)} \\ z_2^{[1](i)}\end{bmatrix}$ is vector of size $\left(n_h \times 1\right) = \left(2 \times 1\right)$;
#
# &emsp; &emsp; $W^{[1]} = \begin{bmatrix}W_1^{[1]} \\ W_2^{[1]}\end{bmatrix} =
# \begin{bmatrix}w_{1,1}^{[1]} & w_{2,1}^{[1]} \\ w_{1,2}^{[1]} & w_{2,2}^{[1]}\end{bmatrix}$ is matrix of size $\left(n_h \times n_x\right) = \left(2 \times 2\right)$;
#
# &emsp; &emsp; $b^{[1]} = \begin{bmatrix}b_1^{[1]} \\ b_2^{[1]}\end{bmatrix}$ is vector of size $\left(n_h \times 1\right) = \left(2 \times 1\right)$.

# %% [markdown]
# Next, the hidden layer activation function needs to be applied for each of the elements in the vector $z^{[1](i)}$. Various activation functions can be used here and in this model you will take the sigmoid function $\sigma\left(x\right) = \frac{1}{1 + e^{-x}}$. Remember that its derivative is $\frac{d\sigma}{dx} = \sigma\left(x\right)\left(1-\sigma\left(x\right)\right)$. The output of the hidden layer is a vector of size $\left(n_h \times 1\right) = \left(2 \times 1\right)$:
#
# $$a^{[1](i)} = \sigma\left(z^{[1](i)}\right) =
# \begin{bmatrix}\sigma\left(z_1^{[1](i)}\right) \\ \sigma\left(z_2^{[1](i)}\right)\end{bmatrix}.\tag{3}$$
#
# Then the hidden layer output gets fed into the output layer of size $n_y = 1$. This was covered in the previous lab, the only difference are: $a^{[1](i)}$ is taken instead of $x^{(i)}$ and layer notation $^{[2]}$ appears to identify all parameters and outputs:
#
# $$z^{[2](i)} = w_1^{[2]} a_1^{[1](i)} + w_2^{[2]} a_2^{[1](i)} + b^{[2]}= W^{[2]} a^{[1](i)} + b^{[2]},\tag{4}$$
#
# &emsp; &emsp; $z^{[2](i)}$ and $b^{[2]}$ are scalars for this model, as $\left(n_y \times 1\right) = \left(1 \times 1\right)$;
#
# &emsp; &emsp; $W^{[2]} = \begin{bmatrix}w_1^{[2]} & w_2^{[2]}\end{bmatrix}$ is vector of size $\left(n_y \times n_h\right) = \left(1 \times 2\right)$.
#
# Finally, the same sigmoid function is used as the output layer activation function:
#
# $$a^{[2](i)} = \sigma\left(z^{[2](i)}\right).\tag{5}$$
#
# Mathematically the two layer neural network model for each training example $x^{(i)}$ can be written with the expressions $(2) - (5)$. Let's rewrite them next to each other for convenience:
#
# \begin{align}
# z^{[1](i)} &= W^{[1]} x^{(i)} + b^{[1]},\\
# a^{[1](i)} &= \sigma\left(z^{[1](i)}\right),\\
# z^{[2](i)} &= W^{[2]} a^{[1](i)} + b^{[2]},\\
# a^{[2](i)} &= \sigma\left(z^{[2](i)}\right).\\
# \tag{6}
# \end{align}
#
# Note, that all of the parameters to be trained in the model are without $^{(i)}$ index - they are independent on the input data.

# %% [markdown]
# Finally, the predictions for some example $x^{(i)}$ can be made taking the output $a^{[2](i)}$ and calculating $\hat{y}$ as: $\hat{y} = \begin{cases} 1 & \text{if } a^{[2](i)} > 0.5, \\ 0 & \text{otherwise }. \end{cases}$.

# %% [markdown]
# <a name='2.2'></a>
# ### 2.2 - Neural Network Model with Two Layers for Multiple Training Examples

# %% [markdown]
# Similarly to the single perceptron model, $m$ training examples can be organised in a matrix $X$ of a shape ($2 \times m$), putting $x^{(i)}$ into columns. Then the model $(6)$ can be rewritten in terms of matrix multiplications:
#
# \begin{align}
# Z^{[1]} &= W^{[1]} X + b^{[1]},\\
# A^{[1]} &= \sigma\left(Z^{[1]}\right),\\
# Z^{[2]} &= W^{[2]} A^{[1]} + b^{[2]},\\
# A^{[2]} &= \sigma\left(Z^{[2]}\right),\\
# \tag{7}
# \end{align}
#
# where $b^{[1]}$ is broadcasted to the matrix of size $\left(n_h \times m\right) = \left(2 \times m\right)$ and $b^{[2]}$ to the vector of size $\left(n_y \times m\right) = \left(1 \times m\right)$. It would be a good exercise for you to have a look at the expressions $(7)$ and check that sizes of the matrices will actually match to perform required multiplications.
#
# You have derived expressions to perform forward propagation. Time to evaluate your model and train it.

# %% [markdown]
# <a name='2.3'></a>
# ### 2.3 - Cost Function and Training

# %% [markdown]
# For the evaluation of this simple neural network you can use the same cost function as for the single perceptron case - log loss function. Originally initialized weights were just some random values, now you need to perform training of the model: find such set of parameters $W^{[1]}$, $b^{[1]}$, $W^{[2]}$, $b^{[2]}$, that will minimize the cost function.
#
# Like in the previous example of a single perceptron neural network, the cost function can be written as:
#
# $$\mathcal{L}\left(W^{[1]}, b^{[1]}, W^{[2]}, b^{[2]}\right) = \frac{1}{m}\sum_{i=1}^{m} L\left(W^{[1]}, b^{[1]}, W^{[2]}, b^{[2]}\right) =  \frac{1}{m}\sum_{i=1}^{m}  \large\left(\small - y^{(i)}\log\left(a^{[2](i)}\right) - (1-y^{(i)})\log\left(1- a^{[2](i)}\right)  \large  \right), \small\tag{8}$$
#
# where $y^{(i)} \in \{0,1\}$ are the original labels and $a^{[2](i)}$ are the continuous output values of the forward propagation step (elements of array $A^{[2]}$).
#
# To minimize it, you can use gradient descent, updating the parameters with the following expressions:
#
# \begin{align}
# W^{[1]} &= W^{[1]} - \alpha \frac{\partial \mathcal{L} }{ \partial W^{[1]} },\\
# b^{[1]} &= b^{[1]} - \alpha \frac{\partial \mathcal{L} }{ \partial b^{[1]} },\\
# W^{[2]} &= W^{[2]} - \alpha \frac{\partial \mathcal{L} }{ \partial W^{[2]} },\\
# b^{[2]} &= b^{[2]} - \alpha \frac{\partial \mathcal{L} }{ \partial b^{[2]} },\\
# \tag{9}
# \end{align}
#
# where $\alpha$ is the learning rate.

# %% [markdown]
# To perform training of the model you need to calculate now $\frac{\partial \mathcal{L} }{ \partial W^{[1]}}$, $\frac{\partial \mathcal{L} }{ \partial b^{[1]}}$, $\frac{\partial \mathcal{L} }{ \partial W^{[2]}}$, $\frac{\partial \mathcal{L} }{ \partial b^{[2]}}$.
#
# Let's start from the end of the neural network. You can rewrite here the corresponding expressions for $\frac{\partial \mathcal{L} }{ \partial W }$ and $\frac{\partial \mathcal{L} }{ \partial b }$ from the single perceptron neural network:
#
# \begin{align}
# \frac{\partial \mathcal{L} }{ \partial W } &=
# \frac{1}{m}\left(A-Y\right)X^T,\\
# \frac{\partial \mathcal{L} }{ \partial b } &=
# \frac{1}{m}\left(A-Y\right)\mathbf{1},\\
# \end{align}
#
# where $\mathbf{1}$ is just a ($m \times 1$) vector of ones. Your one perceptron is in the second layer now, so $W$ will be exchanged with $W^{[2]}$, $b$ with $b^{[2]}$, $A$ with $A^{[2]}$, $X$ with $A^{[1]}$:
#
# \begin{align}
# \frac{\partial \mathcal{L} }{ \partial W^{[2]} } &=
# \frac{1}{m}\left(A^{[2]}-Y\right)\left(A^{[1]}\right)^T,\\
# \frac{\partial \mathcal{L} }{ \partial b^{[2]} } &=
# \frac{1}{m}\left(A^{[2]}-Y\right)\mathbf{1}.\\
# \tag{10}
# \end{align}

# %% [markdown]
# Let's now find $\frac{\partial \mathcal{L} }{ \partial W^{[1]}} =
# \begin{bmatrix}
# \frac{\partial \mathcal{L} }{ \partial w_{1,1}^{[1]}} & \frac{\partial \mathcal{L} }{ \partial w_{2,1}^{[1]}} \\
# \frac{\partial \mathcal{L} }{ \partial w_{1,2}^{[1]}} & \frac{\partial \mathcal{L} }{ \partial w_{2,2}^{[1]}} \end{bmatrix}$. It was shown in the videos that $$\frac{\partial \mathcal{L} }{ \partial w_{1,1}^{[1]}}=\frac{1}{m}\sum_{i=1}^{m} \left(
# \left(a^{[2](i)} - y^{(i)}\right)
# w_1^{[2]}
# \left(a_1^{[1](i)}\left(1-a_1^{[1](i)}\right)\right)
# x_1^{(i)}\right)\tag{11}$$
#
# If you do this accurately for each of the elements $\frac{\partial \mathcal{L} }{ \partial W^{[1]}}$, you will get the following matrix:
#
# $$\frac{\partial \mathcal{L} }{ \partial W^{[1]}} = \begin{bmatrix}
# \frac{\partial \mathcal{L} }{ \partial w_{1,1}^{[1]}} & \frac{\partial \mathcal{L} }{ \partial w_{2,1}^{[1]}} \\
# \frac{\partial \mathcal{L} }{ \partial w_{1,2}^{[1]}} & \frac{\partial \mathcal{L} }{ \partial w_{2,2}^{[1]}} \end{bmatrix}$$
# $$= \frac{1}{m}\begin{bmatrix}
# \sum_{i=1}^{m} \left( \left(a^{[2](i)} - y^{(i)}\right) w_1^{[2]} \left(a_1^{[1](i)}\left(1-a_1^{[1](i)}\right)\right)
# x_1^{(i)}\right) &
# \sum_{i=1}^{m} \left( \left(a^{[2](i)} - y^{(i)}\right) w_1^{[2]} \left(a_1^{[1](i)}\left(1-a_1^{[1](i)}\right)\right)
# x_2^{(i)}\right)  \\
# \sum_{i=1}^{m} \left( \left(a^{[2](i)} - y^{(i)}\right) w_2^{[2]} \left(a_2^{[1](i)}\left(1-a_2^{[1](i)}\right)\right)
# x_1^{(i)}\right) &
# \sum_{i=1}^{m} \left( \left(a^{[2](i)} - y^{(i)}\right) w_2^{[2]} \left(a_2^{[1](i)}\left(1-a_2^{[1](i)}\right)\right)
# x_2^{(i)}\right)\end{bmatrix}\tag{12}$$

# %% [markdown]
# Looking at this, you can notice that all terms and indices somehow are very consistent, so it all can be unified into a matrix form. And that's true! $\left(W^{[2]}\right)^T = \begin{bmatrix}w_1^{[2]} \\ w_2^{[2]}\end{bmatrix}$ of size $\left(n_h \times n_y\right) = \left(2 \times 1\right)$ can be multiplied with the vector $A^{[2]} - Y$ of size $\left(n_y \times m\right) = \left(1 \times m\right)$, resulting in a matrix of size $\left(n_h \times m\right) = \left(2 \times m\right)$:
#
# $$
# \begin{align*}
# \left(W^{[2]}\right)^T \left(A^{[2]} - Y\right) &= \begin{bmatrix}w_1^{[2]} \\ w_2^{[2]}\end{bmatrix} \begin{bmatrix}\left(a^{[2](1)} - y^{(1)}\right) &  \cdots & \left(a^{[2](m)} - y^{(m)}\right)\end{bmatrix} \\
# &= \begin{bmatrix}
# \left(a^{ } - y^{(1)}\right) w_1^{[2]} & \cdots & \left(a^{[2](m)} - y^{(m)}\right) w_1^{[2]} \\
# \left(a^{ } - y^{(1)}\right) w_2^{[2]} & \cdots & \left(a^{[2](m)} - y^{(m)}\right) w_2^{[2]}
# \end{bmatrix}
# \end{align*}
# $$
#
# Now taking matrix $A^{[1]}$ of the same size $\left(n_h \times m\right) = \left(2 \times m\right)$,
#
# $$A^{[1]}
# =\begin{bmatrix}
# a_1^{[1](1)} & \cdots & a_1^{[1](m)} \\
# a_2^{[1](1)} & \cdots & a_2^{[1](m)} \end{bmatrix},$$
#
# you can calculate:
#
# $$A^{[1]}\cdot\left(1-A^{[1]}\right)
# =\begin{bmatrix}
# a_1^{[1](1)}\left(1 - a_1^{[1](1)}\right) & \cdots & a_1^{[1](m)}\left(1 - a_1^{[1](m)}\right) \\
# a_2^{[1](1)}\left(1 - a_2^{[1](1)}\right) & \cdots & a_2^{[1](m)}\left(1 - a_2^{[1](m)}\right) \end{bmatrix},$$
#
# where "$\cdot$" denotes **element by element** multiplication.

# %% [markdown]
# With the element by element multiplication,
#
# $$\left(W^{[2]}\right)^T \left(A^{[2]} - Y\right)\cdot \left(A^{[1]}\cdot\left(1-A^{[1]}\right)\right)=\begin{bmatrix}
# \left(a^{[2](1)} - y^{(1)}\right) w_1^{[2]}\left(a_1^{[1](1)}\left(1 - a_1^{[1](1)}\right)\right) & \cdots & \left(a^{[2](m)} - y^{(m)}\right) w_1^{[2]}\left(a_1^{[1](m)}\left(1 - a_1^{[1](m)}\right)\right) \\
# \left(a^{[2](1)} - y^{(1)}\right) w_2^{[2]}\left(a_2^{[1](1)}\left(1 - a_2^{[1](1)}\right)\right) & \cdots & \left(a^{[2](m)} - y^{(m)}\right) w_2^{[2]} \left(a_2^{[1](m)}\left(1 - a_2^{[1](m)}\right)\right) \end{bmatrix}.$$
#
# If you perform matrix multiplication with $X^T$ of size $\left(m \times n_x\right) = \left(m \times 2\right)$, you will get matrix of size $\left(n_h \times n_x\right) = \left(2 \times 2\right)$:
#
# $$\left(\left(W^{[2]}\right)^T \left(A^{[2]} - Y\right)\cdot \left(A^{[1]}\cdot\left(1-A^{[1]}\right)\right)\right)X^T =
# \begin{bmatrix}
# \left(a^{[2](1)} - y^{(1)}\right) w_1^{[2]}\left(a_1^{[1](1)}\left(1 - a_1^{[1](1)}\right)\right) & \cdots & \left(a^{[2](m)} - y^{(m)}\right) w_1^{[2]}\left(a_1^{[1](m)}\left(1 - a_1^{[1](m)}\right)\right) \\
# \left(a^{[2](1)} - y^{(1)}\right) w_2^{[2]}\left(a_2^{[1](1)}\left(1 - a_2^{[1](1)}\right)\right) & \cdots & \left(a^{[2](m)} - y^{(m)}\right) w_2^{[2]} \left(a_2^{[1](m)}\left(1 - a_2^{[1](m)}\right)\right) \end{bmatrix}
# \begin{bmatrix}
# x_1^{(1)} & x_2^{(1)} \\
# \cdots & \cdots \\
# x_1^{(m)} & x_2^{(m)}
# \end{bmatrix}$$
# $$=\begin{bmatrix}
# \sum_{i=1}^{m} \left( \left(a^{[2](i)} - y^{(i)}\right) w_1^{[2]} \left(a_1^{[1](i)}\left(1 - a_1^{[1](i)}\right) \right)
# x_1^{(i)}\right) &
# \sum_{i=1}^{m} \left( \left(a^{[2](i)} - y^{(i)}\right) w_1^{[2]} \left(a_1^{[1](i)}\left(1-a_1^{[1](i)}\right)\right)
# x_2^{(i)}\right)  \\
# \sum_{i=1}^{m} \left( \left(a^{[2](i)} - y^{(i)}\right) w_2^{[2]} \left(a_2^{[1](i)}\left(1-a_2^{[1](i)}\right)\right)
# x_1^{(i)}\right) &
# \sum_{i=1}^{m} \left( \left(a^{[2](i)} - y^{(i)}\right) w_2^{[2]} \left(a_2^{[1](i)}\left(1-a_2^{[1](i)}\right)\right)
# x_2^{(i)}\right)\end{bmatrix}$$
#
# This is exactly like in the expression $(12)$! So, $\frac{\partial \mathcal{L} }{ \partial W^{[1]}}$ can be written as a mixture of multiplications:
#
# $$\frac{\partial \mathcal{L} }{ \partial W^{[1]}} = \frac{1}{m}\left(\left(W^{[2]}\right)^T \left(A^{[2]} - Y\right)\cdot \left(A^{[1]}\cdot\left(1-A^{[1]}\right)\right)\right)X^T\tag{13},$$
#
# where "$\cdot$" denotes element by element multiplications.

# %% [markdown]
# Vector $\frac{\partial \mathcal{L} }{ \partial b^{[1]}}$ can be found very similarly, but the last terms in the chain rule will be equal to $1$, i.e. $\frac{\partial z_1^{[1](i)}}{ \partial b_1^{[1]}} = 1$. Thus,
#
# $$\frac{\partial \mathcal{L} }{ \partial b^{[1]}} = \frac{1}{m}\left(\left(W^{[2]}\right)^T \left(A^{[2]} - Y\right)\cdot \left(A^{[1]}\cdot\left(1-A^{[1]}\right)\right)\right)\mathbf{1},\tag{14}$$
#
# where $\mathbf{1}$ is a ($m \times 1$) vector of ones.
#
# Expressions $(10)$, $(13)$ and $(14)$ can be used for the parameters update $(9)$ performing backward propagation:
#
# \begin{align}
# \frac{\partial \mathcal{L} }{ \partial W^{[2]} } &=
# \frac{1}{m}\left(A^{[2]}-Y\right)\left(A^{[1]}\right)^T,\\
# \frac{\partial \mathcal{L} }{ \partial b^{[2]} } &=
# \frac{1}{m}\left(A^{[2]}-Y\right)\mathbf{1},\\
# \frac{\partial \mathcal{L} }{ \partial W^{[1]}} &= \frac{1}{m}\left(\left(W^{[2]}\right)^T \left(A^{[2]} - Y\right)\cdot \left(A^{[1]}\cdot\left(1-A^{[1]}\right)\right)\right)X^T,\\
# \frac{\partial \mathcal{L} }{ \partial b^{[1]}} &= \frac{1}{m}\left(\left(W^{[2]}\right)^T \left(A^{[2]} - Y\right)\cdot \left(A^{[1]}\cdot\left(1-A^{[1]}\right)\right)\right)\mathbf{1},\\
# \tag{15}
# \end{align}
#
# where $\mathbf{1}$ is a ($m \times 1$) vector of ones.

# %% [markdown]
# So, to understand deeply and properly how neural networks perform and get trained, **you do need knowledge of linear algebra and calculus joined together**! But do not worry! All together it is not that scary if you do it step by step accurately with understanding of maths.
#
# Time to implement this all in the code!

# %% [markdown]
# <a name='2.2'></a>
# ### 2.2 - Dataset
#
# First, let's get the dataset you will work on. The following code will create $m=2000$ data points $(x_1, x_2)$ and save them in the `NumPy` array `X` of a shape $(2 \times m)$ (in the columns of the array). The labels ($0$: blue, $1$: red) will be saved in the `NumPy` array `Y` of a shape $(1 \times m)$.

# %%
m = 2000
samples, labels = make_blobs(n_samples=m, 
                             centers=([2.5, 3], [6.7, 7.9], [2.1, 7.9], [7.4, 2.8]), 
                             cluster_std=1.1,
                             random_state=0)
labels[(labels == 0) | (labels == 1)] = 1
labels[(labels == 2) | (labels == 3)] = 0
X = np.transpose(samples)
Y = labels.reshape((1, m))

plt.scatter(X[0, :], X[1, :], c=Y, cmap=colors.ListedColormap(['blue', 'red']));

print ('The shape of X is: ' + str(X.shape))
print ('The shape of Y is: ' + str(Y.shape))
print ('I have m = %d training examples!' % (m))
# Out:
# The shape of X is: (2, 2000)
# The shape of Y is: (1, 2000)
# I have m = 2000 training examples!

# %% [markdown]
# <a name='2.3'></a>
# ### 2.3 - Define Activation Function

# %% [markdown]
# <a name='ex01'></a>
# ### Exercise 1
#
# Define sigmoid activation function $\sigma\left(z\right) =\frac{1}{1+e^{-z}} $.

# %%
def sigmoid(z):
    ### START CODE HERE ### (~ 1 line of code)
    res = 1/(1 + np.exp(-z))
    ### END CODE HERE ###
    
    return res

# %%
print("sigmoid(-2) = " + str(sigmoid(-2)))
print("sigmoid(0) = " + str(sigmoid(0)))
print("sigmoid(3.5) = " + str(sigmoid(3.5)))
# Out:
# sigmoid(-2) = 0.11920292202211755
# sigmoid(0) = 0.5
# sigmoid(3.5) = 0.9706877692486436

# %% [markdown]
# ##### __Expected Output__
#
# Note: the values may vary in the last decimal places.
#
# ```Python
# sigmoid(-2) = 0.11920292202211755
# sigmoid(0) = 0.5
# sigmoid(3.5) = 0.9706877692486436
# ```

# %%
w3_unittest.test_sigmoid(sigmoid)
# Out:
#  All tests passed

# %% [markdown]
# <a name='3'></a>
# ## 3 - Implementation of the Neural Network Model with Two Layers

# %% [markdown]
# <a name='3.1'></a>
# ### 3.1 - Defining the Neural Network Structure

# %% [markdown]
# <a name='ex02'></a>
# ### Exercise 2
#
# Define three variables:
# - `n_x`: the size of the input layer
# - `n_h`: the size of the hidden layer (set it equal to 2 for now)
# - `n_y`: the size of the output layer

# %% [markdown]
# <details>
# <summary>
#     <font size="3" color="darkgreen"><b>Hint</b></font>
# </summary>
# <p>
# <ul>
#     Use shapes of X and Y to find n_x and n_y:
#     <li>the size of the input layer n_x equals to the size of the input vectors placed in the columns of the array X,</li>
#     <li>the outpus for each of the data point will be saved in the columns of the the array Y.</li>
# </ul>
# </p>

# %%
# GRADED FUNCTION: layer_sizes

def layer_sizes(X, Y):
    """
    Arguments:
    X -- input dataset of shape (input size, number of examples)
    Y -- labels of shape (output size, number of examples)
    
    Returns:
    n_x -- the size of the input layer
    n_h -- the size of the hidden layer
    n_y -- the size of the output layer
    """
    ### START CODE HERE ### (~ 3 lines of code)
    # Size of input layer.
    n_x = X.shape[0]
    # Size of hidden layer.
    n_h = 2
    # Size of output layer.
    n_y = Y.shape[0]
    ### END CODE HERE ###
    return (n_x, n_h, n_y)

# %%
(n_x, n_h, n_y) = layer_sizes(X, Y)
print("The size of the input layer is: n_x = " + str(n_x))
print("The size of the hidden layer is: n_h = " + str(n_h))
print("The size of the output layer is: n_y = " + str(n_y))
# Out:
# The size of the input layer is: n_x = 2
# The size of the hidden layer is: n_h = 2
# The size of the output layer is: n_y = 1

# %% [markdown]
# ##### __Expected Output__
#
# ```Python
# The size of the input layer is: n_x = 2
# The size of the hidden layer is: n_h = 2
# The size of the output layer is: n_y = 1
# ```

# %%
w3_unittest.test_layer_sizes(layer_sizes)
# Out:
#  All tests passed

# %% [markdown]
# <a name='3.2'></a>
# ### 3.2 - Initialize the Model's Parameters

# %% [markdown]
# <a name='ex03'></a>
# ### Exercise 3
#
# Implement the function `initialize_parameters()`.
#
# **Instructions**:
# - Make sure your parameters' sizes are right. Refer to the neural network figure above if needed.
# - You will initialize the weights matrix with random values.
#     - Use: `np.random.randn(a,b) * 0.01` to randomly initialize a matrix of shape (a,b).
# - You will initialize the bias vector as zeros.
#     - Use: `np.zeros((a,b))` to initialize a matrix of shape (a,b) with zeros.

# %%
# GRADED FUNCTION: initialize_parameters

def initialize_parameters(n_x, n_h, n_y):
    """
    Argument:
    n_x -- size of the input layer
    n_h -- size of the hidden layer
    n_y -- size of the output layer
    
    Returns:
    params -- python dictionary containing your parameters:
                    W1 -- weight matrix of shape (n_h, n_x)
                    b1 -- bias vector of shape (n_h, 1)
                    W2 -- weight matrix of shape (n_y, n_h)
                    b2 -- bias vector of shape (n_y, 1)
    """
    
    ### START CODE HERE ### (~ 4 lines of code)
    W1 = np.random.randn(n_h, n_x) * 0.01
    b1 = np.zeros((n_h, 1))
    W2 = np.random.randn(n_y, n_h) * 0.01
    b2 = np.zeros((n_y, 1))
    ### END CODE HERE ###
    
    assert (W1.shape == (n_h, n_x))
    assert (b1.shape == (n_h, 1))
    assert (W2.shape == (n_y, n_h))
    assert (b2.shape == (n_y, 1))
    
    parameters = {"W1": W1,
                  "b1": b1,
                  "W2": W2,
                  "b2": b2}
    
    return parameters

# %%
parameters = initialize_parameters(n_x, n_h, n_y)

print("W1 = " + str(parameters["W1"]))
print("b1 = " + str(parameters["b1"]))
print("W2 = " + str(parameters["W2"]))
print("b2 = " + str(parameters["b2"]))
# Out:
# W1 = [[ 0.01788628  0.0043651 ]
#  [ 0.00096497 -0.01863493]]
# b1 = [[0.]
#  [0.]]
# W2 = [[-0.00277388 -0.00354759]]
# b2 = [[0.]]

# %% [markdown]
# ##### __Expected Output__
# Note: the elements of the arrays W1 and W2 maybe be different due to random initialization. You can try to restart the kernel to get the same values.
#
# ```Python
# W1 = [[ 0.01788628  0.0043651 ]
#  [ 0.00096497 -0.01863493]]
# b1 = [[0.]
#  [0.]]
# W2 = [[-0.00277388 -0.00354759]]
# b2 = [[0.]]
# ```

# %%
# Note: 
# Actual values are not checked here in the unit tests (due to random initialization).
w3_unittest.test_initialize_parameters(initialize_parameters)
# Out:
#  All tests passed

# %% [markdown]
# <a name='3.3'></a>
# ### 3.3 - The Loop

# %% [markdown]
# <a name='ex04'></a>
# ### Exercise 4
#
# Implement `forward_propagation()`.
#
# **Instructions**:
# - Look above at the mathematical representation $(7)$ of your classifier (section [2.2](#2.2)):
# \begin{align}
# Z^{[1]} &= W^{[1]} X + b^{[1]},\\
# A^{[1]} &= \sigma\left(Z^{[1]}\right),\\
# Z^{[2]} &= W^{[2]} A^{[1]} + b^{[2]},\\
# A^{[2]} &= \sigma\left(Z^{[2]}\right).\\
# \end{align}
# - The steps you have to implement are:
#     1. Retrieve each parameter from the dictionary "parameters" (which is the output of `initialize_parameters()`) by using `parameters[".."]`.
#     2. Implement Forward Propagation. Compute `Z1` multiplying matrices `W1`, `X` and adding vector `b1`. Then find `A1` using the `sigmoid` activation function. Perform similar computations for `Z2` and `A2`.

# %%
# GRADED FUNCTION: forward_propagation

def forward_propagation(X, parameters):
    """
    Argument:
    X -- input data of size (n_x, m)
    parameters -- python dictionary containing your parameters (output of initialization function)
    
    Returns:
    A2 -- the sigmoid output of the second activation
    cache -- python dictionary containing Z1, A1, Z2, A2 
    (that simplifies the calculations in the back propagation step)
    """
    # Retrieve each parameter from the dictionary "parameters".
    ### START CODE HERE ### (~ 4 lines of code)
    W1 = parameters["W1"]
    b1 = parameters["b1"]
    W2 = parameters["W2"]
    b2 = parameters["b2"]
    ### END CODE HERE ###
    
    # Implement forward propagation to calculate A2.
    ### START CODE HERE ### (~ 4 lines of code)
    Z1 = np.matmul(W1, X) + b1
    A1 = sigmoid(Z1)
    Z2 = np.matmul(W2, A1) + b2
    A2 = sigmoid(Z2)
    ### END CODE HERE ###
    
    assert(A2.shape == (n_y, X.shape[1]))

    cache = {"Z1": Z1,
             "A1": A1,
             "Z2": Z2,
             "A2": A2}
    
    return A2, cache

# %%
A2, cache = forward_propagation(X, parameters)

print(A2)
# Out:
# [[0.49920157 0.49922234 0.49921223 ... 0.49921215 0.49921043 0.49920665]]

# %% [markdown]
# ##### __Expected Output__
# Note: the elements of the array A2 maybe be different depending on the initial parameters. If you would like to get exactly the same output, try to restart the Kernel and rerun the notebook.
#
# ```Python
# [[0.49920157 0.49922234 0.49921223 ... 0.49921215 0.49921043 0.49920665]]
# ```

# %%
# Note: 
# Actual values are not checked here in the unit tests (due to random initialization).
w3_unittest.test_forward_propagation(forward_propagation)
# Out:
#  All tests passed

# %% [markdown]
# Remember, that your weights were just initialized with some random values, so the model has not been trained yet.

# %% [markdown]
# <a name='ex05'></a>
# ### Exercise 5
#
# Define a cost function $(8)$ which will be used to train the model:
#
# $$\mathcal{L}\left(W, b\right)  = \frac{1}{m}\sum_{i=1}^{m}  \large\left(\small - y^{(i)}\log\left(a^{(i)}\right) - (1-y^{(i)})\log\left(1- a^{(i)}\right)  \large  \right) \small.$$

# %%
def compute_cost(A2, Y):
    """
    Computes the cost function as a log loss
    
    Arguments:
    A2 -- The output of the neural network of shape (1, number of examples)
    Y -- "true" labels vector of shape (1, number of examples)
    
    Returns:
    cost -- log loss
    
    """
    # Number of examples.
    m = Y.shape[1]
    
    ### START CODE HERE ### (~ 2 lines of code)
    logloss = - np.multiply(np.log(A2), Y) - np.multiply(np.log(1 - A2), 1 - Y)
    cost = 1/m * np.sum(logloss)
    ### END CODE HERE ###

    assert(isinstance(cost, float))
    
    return cost

# %%
print("cost = " + str(compute_cost(A2, Y)))
# Out:
# cost = 0.6931477703826823

# %% [markdown]
# ##### __Expected Output__
# Note: the elements of the arrays W1 and W2 maybe be different!
#
# ```Python
# cost = 0.6931477703826823
# ```

# %%
# Note: 
# Actual values are not checked here in the unit tests (due to random initialization).
w3_unittest.test_compute_cost(compute_cost, A2)
# Out:
#  All tests passed

# %% [markdown]
# Calculate partial derivatives as shown in $(15)$:
#
# \begin{align}
# \frac{\partial \mathcal{L} }{ \partial W^{[2]} } &=
# \frac{1}{m}\left(A^{[2]}-Y\right)\left(A^{[1]}\right)^T,\\
# \frac{\partial \mathcal{L} }{ \partial b^{[2]} } &=
# \frac{1}{m}\left(A^{[2]}-Y\right)\mathbf{1},\\
# \frac{\partial \mathcal{L} }{ \partial W^{[1]}} &= \frac{1}{m}\left(\left(W^{[2]}\right)^T \left(A^{[2]} - Y\right)\cdot \left(A^{[1]}\cdot\left(1-A^{[1]}\right)\right)\right)X^T,\\
# \frac{\partial \mathcal{L} }{ \partial b^{[1]}} &= \frac{1}{m}\left(\left(W^{[2]}\right)^T \left(A^{[2]} - Y\right)\cdot \left(A^{[1]}\cdot\left(1-A^{[1]}\right)\right)\right)\mathbf{1}.\\
# \end{align}

# %%
def backward_propagation(parameters, cache, X, Y):
    """
    Implements the backward propagation, calculating gradients
    
    Arguments:
    parameters -- python dictionary containing our parameters 
    cache -- python dictionary containing Z1, A1, Z2, A2
    X -- input data of shape (n_x, number of examples)
    Y -- "true" labels vector of shape (n_y, number of examples)
    
    Returns:
    grads -- python dictionary containing gradients with respect to different parameters
    """
    m = X.shape[1]
    
    # First, retrieve W from the dictionary "parameters".
    W1 = parameters["W1"]
    W2 = parameters["W2"]
    
    # Retrieve also A1 and A2 from dictionary "cache".
    A1 = cache["A1"]
    A2 = cache["A2"]
    
    # Backward propagation: calculate partial derivatives denoted as dW1, db1, dW2, db2 for simplicity. 
    dZ2 = A2 - Y
    dW2 = 1/m * np.dot(dZ2, A1.T)
    db2 = 1/m * np.sum(dZ2, axis = 1, keepdims = True)
    dZ1 = np.dot(W2.T, dZ2) * A1 * (1 - A1)
    dW1 = 1/m * np.dot(dZ1, X.T)
    db1 = 1/m * np.sum(dZ1, axis = 1, keepdims = True)
    
    grads = {"dW1": dW1,
             "db1": db1,
             "dW2": dW2,
             "db2": db2}
    
    return grads

grads = backward_propagation(parameters, cache, X, Y)

print("dW1 = " + str(grads["dW1"]))
print("db1 = " + str(grads["db1"]))
print("dW2 = " + str(grads["dW2"]))
print("db2 = " + str(grads["db2"]))
# Out:
# dW1 = [[-1.49856632e-05  1.67791519e-05]
#  [-2.12394543e-05  2.43895135e-05]]
# db1 = [[5.11207671e-07]
#  [7.06236219e-07]]
# dW2 = [[-0.00032641 -0.0002606 ]]
# db2 = [[-0.00078732]]

# %% [markdown]
# <a name='ex06'></a>
# ### Exercise 6
#
# Implement `update_parameters()`.
#
# **Instructions**:
# - Update parameters as shown in $(9)$ (section [2.3](#2.3)):
# \begin{align}
# W^{[1]} &= W^{[1]} - \alpha \frac{\partial \mathcal{L} }{ \partial W^{[1]} },\\
# b^{[1]} &= b^{[1]} - \alpha \frac{\partial \mathcal{L} }{ \partial b^{[1]} },\\
# W^{[2]} &= W^{[2]} - \alpha \frac{\partial \mathcal{L} }{ \partial W^{[2]} },\\
# b^{[2]} &= b^{[2]} - \alpha \frac{\partial \mathcal{L} }{ \partial b^{[2]} }.\\
# \end{align}
# - The steps you have to implement are:
#     1. Retrieve each parameter from the dictionary "parameters" (which is the output of `initialize_parameters()`) by using `parameters[".."]`.
#     2. Retrieve each derivative from the dictionary "grads" (which is the output of `backward_propagation()`) by using `grads[".."]`.
#     3. Update parameters.

# %%
def update_parameters(parameters, grads, learning_rate=1.2):
    """
    Updates parameters using the gradient descent update rule
    
    Arguments:
    parameters -- python dictionary containing parameters 
    grads -- python dictionary containing gradients
    learning_rate -- learning rate for gradient descent
    
    Returns:
    parameters -- python dictionary containing updated parameters 
    """
    # Retrieve each parameter from the dictionary "parameters".
    ### START CODE HERE ### (~ 4 lines of code)
    W1 = parameters["W1"]
    b1 = parameters["b1"]
    W2 = parameters["W2"]
    b2 = parameters["b2"]
    ### END CODE HERE ###
    
    # Retrieve each gradient from the dictionary "grads".
    ### START CODE HERE ### (~ 4 lines of code)
    dW1 = grads["dW1"]
    db1 = grads["db1"]
    dW2 = grads["dW2"]
    db2 = grads["db2"]
    ### END CODE HERE ###
    
    # Update rule for each parameter.
    ### START CODE HERE ### (~ 4 lines of code)
    W1 = W1 - learning_rate * dW1
    b1 = b1 - learning_rate * db1
    W2 = W2 - learning_rate * dW2
    b2 = b2 - learning_rate * db2
    ### END CODE HERE ###
    
    parameters = {"W1": W1,
                  "b1": b1,
                  "W2": W2,
                  "b2": b2}
    
    return parameters

# %%
parameters_updated = update_parameters(parameters, grads)

print("W1 updated = " + str(parameters_updated["W1"]))
print("b1 updated = " + str(parameters_updated["b1"]))
print("W2 updated = " + str(parameters_updated["W2"]))
print("b2 updated = " + str(parameters_updated["b2"]))
# Out:
# W1 updated = [[ 0.01790427  0.00434496]
#  [ 0.00099046 -0.01866419]]
# b1 updated = [[-6.13449205e-07]
#  [-8.47483463e-07]]
# W2 updated = [[-0.00238219 -0.00323487]]
# b2 updated = [[0.00094478]]

# %% [markdown]
# ##### __Expected Output__
# Note: the actual values can be different!
#
# ```Python
# W1 updated = [[ 0.01790427  0.00434496]
#  [ 0.00099046 -0.01866419]]
# b1 updated = [[-6.13449205e-07]
#  [-8.47483463e-07]]
# W2 updated = [[-0.00238219 -0.00323487]]
# b2 updated = [[0.00094478]]
# ```

# %%
w3_unittest.test_update_parameters(update_parameters)
# Out:
#  All tests passed

# %% [markdown]
# <a name='3.4'></a>
# ### 3.4 - Integrate parts 3.1, 3.2 and 3.3 in nn_model()

# %% [markdown]
# <a name='ex07'></a>
# ### Exercise 7
#
# Build your neural network model in `nn_model()`.
#
# **Instructions**: The neural network model has to use the previous functions in the right order.

# %%
# GRADED FUNCTION: nn_model

def nn_model(X, Y, n_h, num_iterations=10, learning_rate=1.2, print_cost=False):
    """
    Arguments:
    X -- dataset of shape (n_x, number of examples)
    Y -- labels of shape (n_y, number of examples)
    num_iterations -- number of iterations in the loop
    learning_rate -- learning rate parameter for gradient descent
    print_cost -- if True, print the cost every iteration
    
    Returns:
    parameters -- parameters learnt by the model. They can then be used to predict.
    """
    
    n_x = layer_sizes(X, Y)[0]
    n_y = layer_sizes(X, Y)[2]
    
    # Initialize parameters.
    ### START CODE HERE ### (~ 1 line of code)
    parameters = initialize_parameters(n_x, n_h, n_y)
    ### END CODE HERE ###
    
    # Loop.
    for i in range(0, num_iterations):
         
        ### START CODE HERE ### (~ 4 lines of code)
        # Forward propagation. Inputs: "X, parameters". Outputs: "A2, cache".
        A2, cache = forward_propagation(X, parameters)
        
        # Cost function. Inputs: "A2, Y". Outputs: "cost".
        cost = compute_cost(A2, Y)
        
        # Backpropagation. Inputs: "parameters, cache, X, Y". Outputs: "grads".
        grads = backward_propagation(parameters, cache, X, Y)
        
        # Gradient descent parameter update. Inputs: "parameters, grads, learning_rate". Outputs: "parameters".
        parameters = update_parameters(parameters, grads, learning_rate)
        ### END CODE HERE ###
        
        # Print the cost every iteration.
        if print_cost:
            print ("Cost after iteration %i: %f" %(i, cost))

    return parameters

# %%
parameters = nn_model(X, Y, n_h=2, num_iterations=3000, learning_rate=1.2, print_cost=True)
print("W1 = " + str(parameters["W1"]))
print("b1 = " + str(parameters["b1"]))
print("W2 = " + str(parameters["W2"]))
print("b2 = " + str(parameters["b2"]))

W1 = parameters["W1"]
b1 = parameters["b1"]
W2 = parameters["W2"]
b2 = parameters["b2"]
# Out:
# Cost after iteration 0: 0.693166
# Cost after iteration 1: 0.693153
# Cost after iteration 2: 0.693149
# Cost after iteration 3: 0.693148
# Cost after iteration 4: 0.693147
# Cost after iteration 5: 0.693147
# Cost after iteration 6: 0.693147
# Cost after iteration 7: 0.693147
# Cost after iteration 8: 0.693147
# Cost after iteration 9: 0.693147
# Cost after iteration 10: 0.693147
# Cost after iteration 11: 0.693147
# Cost after iteration 12: 0.693147
# Cost after iteration 13: 0.693147
# Cost after iteration 14: 0.693147
# Cost after iteration 15: 0.693147
# Cost after iteration 16: 0.693147
# Cost after iteration 17: 0.693147
# Cost after iteration 18: 0.693147
# Cost after iteration 19: 0.693147
# Cost after iteration 20: 0.693146
# Cost after iteration 21: 0.693146
# Cost after iteration 22: 0.693146
# Cost after iteration 23: 0.693146
# Cost after iteration 24: 0.693146
# Cost after iteration 25: 0.693146
# Cost after iteration 26: 0.693146
# Cost after iteration 27: 0.693146
# Cost after iteration 28: 0.693146
# Cost after iteration 29: 0.693146
# Cost after iteration 30: 0.693146
# Cost after iteration 31: 0.693146
# Cost after iteration 32: 0.693146
# Cost after iteration 33: 0.693146
# Cost after iteration 34: 0.693146
# Cost after iteration 35: 0.693146
# Cost after iteration 36: 0.693146
# Cost after iteration 37: 0.693146
# Cost after iteration 38: 0.693146
# Cost after iteration 39: 0.693146
# Cost after iteration 40: 0.693146
# Cost after iteration 41: 0.693146
# Cost after iteration 42: 0.693146
# Cost after iteration 43: 0.693145
# Cost after iteration 44: 0.693145
# Cost after iteration 45: 0.693145
# Cost after iteration 46: 0.693145
# Cost after iteration 47: 0.693145
# Cost after iteration 48: 0.693145
# Cost after iteration 49: 0.693145
# Cost after iteration 50: 0.693145
# Cost after iteration 51: 0.693145
# Cost after iteration 52: 0.693145
# Cost after iteration 53: 0.693145
# Cost after iteration 54: 0.693145
# Cost after iteration 55: 0.693145
# Cost after iteration 56: 0.693145
# Cost after iteration 57: 0.693145
# Cost after iteration 58: 0.693145
# Cost after iteration 59: 0.693145
# Cost after iteration 60: 0.693145
# Cost after iteration 61: 0.693144
# Cost after iteration 62: 0.693144
# Cost after iteration 63: 0.693144
# Cost after iteration 64: 0.693144
# Cost after iteration 65: 0.693144
# Cost after iteration 66: 0.693144
# Cost after iteration 67: 0.693144
# Cost after iteration 68: 0.693144
# Cost after iteration 69: 0.693144
# Cost after iteration 70: 0.693144
# Cost after iteration 71: 0.693144
# Cost after iteration 72: 0.693144
# Cost after iteration 73: 0.693144
# Cost after iteration 74: 0.693143
# Cost after iteration 75: 0.693143
# Cost after iteration 76: 0.693143
# Cost after iteration 77: 0.693143
# Cost after iteration 78: 0.693143
# Cost after iteration 79: 0.693143
# Cost after iteration 80: 0.693143
# Cost after iteration 81: 0.693143
# Cost after iteration 82: 0.693143
# Cost after iteration 83: 0.693143
# Cost after iteration 84: 0.693143
# Cost after iteration 85: 0.693142
# Cost after iteration 86: 0.693142
# Cost after iteration 87: 0.693142
# Cost after iteration 88: 0.693142
# Cost after iteration 89: 0.693142
# Cost after iteration 90: 0.693142
# Cost after iteration 91: 0.693142
# Cost after iteration 92: 0.693142
# Cost after iteration 93: 0.693142
# Cost after iteration 94: 0.693141
# Cost after iteration 95: 0.693141
# Cost after iteration 96: 0.693141
# Cost after iteration 97: 0.693141
# Cost after iteration 98: 0.693141
# Cost after iteration 99: 0.693141
# Cost after iteration 100: 0.693141
# Cost after iteration 101: 0.693140
# Cost after iteration 102: 0.693140
# Cost after iteration 103: 0.693140
# Cost after iteration 104: 0.693140
# Cost after iteration 105: 0.693140
# Cost after iteration 106: 0.693140
# Cost after iteration 107: 0.693139
# Cost after iteration 108: 0.693139
# Cost after iteration 109: 0.693139
# Cost after iteration 110: 0.693139
# Cost after iteration 111: 0.693139
# Cost after iteration 112: 0.693139
# Cost after iteration 113: 0.693138
# Cost after iteration 114: 0.693138
# Cost after iteration 115: 0.693138
# Cost after iteration 116: 0.693138
# Cost after iteration 117: 0.693138
# Cost after iteration 118: 0.693137
# Cost after iteration 119: 0.693137
# Cost after iteration 120: 0.693137
# Cost after iteration 121: 0.693137
# Cost after iteration 122: 0.693137
# Cost after iteration 123: 0.693136
# Cost after iteration 124: 0.693136
# Cost after iteration 125: 0.693136
# Cost after iteration 126: 0.693136
# Cost after iteration 127: 0.693135
# Cost after iteration 128: 0.693135
# Cost after iteration 129: 0.693135
# Cost after iteration 130: 0.693135
# Cost after iteration 131: 0.693134
# Cost after iteration 132: 0.693134
# Cost after iteration 133: 0.693134
# Cost after iteration 134: 0.693133
# Cost after iteration 135: 0.693133
# Cost after iteration 136: 0.693133
# Cost after iteration 137: 0.693132
# Cost after iteration 138: 0.693132
# Cost after iteration 139: 0.693132
# Cost after iteration 140: 0.693131
# Cost after iteration 141: 0.693131
# Cost after iteration 142: 0.693131
# Cost after iteration 143: 0.693130
# Cost after iteration 144: 0.693130
# Cost after iteration 145: 0.693130
# Cost after iteration 146: 0.693129
# Cost after iteration 147: 0.693129
# Cost after iteration 148: 0.693128
# Cost after iteration 149: 0.693128
# Cost after iteration 150: 0.693128
# Cost after iteration 151: 0.693127
# Cost after iteration 152: 0.693127
# Cost after iteration 153: 0.693126
# Cost after iteration 154: 0.693126
# Cost after iteration 155: 0.693125
# Cost after iteration 156: 0.693125
# Cost after iteration 157: 0.693124
# Cost after iteration 158: 0.693124
# Cost after iteration 159: 0.693123
# Cost after iteration 160: 0.693123
# Cost after iteration 161: 0.693122
# Cost after iteration 162: 0.693121
# Cost after iteration 163: 0.693121
# Cost after iteration 164: 0.693120
# Cost after iteration 165: 0.693119
# Cost after iteration 166: 0.693119
# Cost after iteration 167: 0.693118
# Cost after iteration 168: 0.693117
# Cost after iteration 169: 0.693117
# Cost after iteration 170: 0.693116
# Cost after iteration 171: 0.693115
# Cost after iteration 172: 0.693114
# Cost after iteration 173: 0.693113
# Cost after iteration 174: 0.693113
# Cost after iteration 175: 0.693112
# Cost after iteration 176: 0.693111
# Cost after iteration 177: 0.693110
# Cost after iteration 178: 0.693109
# Cost after iteration 179: 0.693108
# Cost after iteration 180: 0.693107
# Cost after iteration 181: 0.693106
# Cost after iteration 182: 0.693105
# Cost after iteration 183: 0.693103
# Cost after iteration 184: 0.693102
# Cost after iteration 185: 0.693101
# Cost after iteration 186: 0.693100
# Cost after iteration 187: 0.693098
# Cost after iteration 188: 0.693097
# Cost after iteration 189: 0.693095
# Cost after iteration 190: 0.693094
# Cost after iteration 191: 0.693092
# Cost after iteration 192: 0.693091
# Cost after iteration 193: 0.693089
# Cost after iteration 194: 0.693087
# Cost after iteration 195: 0.693085
# Cost after iteration 196: 0.693083
# Cost after iteration 197: 0.693081
# Cost after iteration 198: 0.693079
# Cost after iteration 199: 0.693077
# Cost after iteration 200: 0.693075
# Cost after iteration 201: 0.693072
# Cost after iteration 202: 0.693069
# Cost after iteration 203: 0.693067
# Cost after iteration 204: 0.693064
# Cost after iteration 205: 0.693061
# Cost after iteration 206: 0.693057
# Cost after iteration 207: 0.693054
# Cost after iteration 208: 0.693050
# Cost after iteration 209: 0.693047
# Cost after iteration 210: 0.693043
# Cost after iteration 211: 0.693038
# Cost after iteration 212: 0.693034
# Cost after iteration 213: 0.693029
# Cost after iteration 214: 0.693023
# Cost after iteration 215: 0.693018
# Cost after iteration 216: 0.693012
# Cost after iteration 217: 0.693005
# Cost after iteration 218: 0.692998
# Cost after iteration 219: 0.692991
# Cost after iteration 220: 0.692983
# Cost after iteration 221: 0.692974
# Cost after iteration 222: 0.692965
# Cost after iteration 223: 0.692955
# Cost after iteration 224: 0.692943
# Cost after iteration 225: 0.692931
# Cost after iteration 226: 0.692918
# Cost after iteration 227: 0.692904
# Cost after iteration 228: 0.692888
# Cost after iteration 229: 0.692870
# Cost after iteration 230: 0.692851
# Cost after iteration 231: 0.692829
# Cost after iteration 232: 0.692805
# Cost after iteration 233: 0.692778
# Cost after iteration 234: 0.692749
# Cost after iteration 235: 0.692715
# Cost after iteration 236: 0.692677
# Cost after iteration 237: 0.692635
# Cost after iteration 238: 0.692587
# Cost after iteration 239: 0.692532
# Cost after iteration 240: 0.692470
# Cost after iteration 241: 0.692398
# Cost after iteration 242: 0.692316
# Cost after iteration 243: 0.692221
# Cost after iteration 244: 0.692112
# Cost after iteration 245: 0.691985
# Cost after iteration 246: 0.691837
# Cost after iteration 247: 0.691665
# Cost after iteration 248: 0.691463
# Cost after iteration 249: 0.691227
# Cost after iteration 250: 0.690949
# Cost after iteration 251: 0.690623
# Cost after iteration 252: 0.690240
# Cost after iteration 253: 0.689791
# Cost after iteration 254: 0.689264
# Cost after iteration 255: 0.688648
# Cost after iteration 256: 0.687929
# Cost after iteration 257: 0.687096
# Cost after iteration 258: 0.686136
# Cost after iteration 259: 0.685036
# Cost after iteration 260: 0.683786
# Cost after iteration 261: 0.682379
# Cost after iteration 262: 0.680809
# Cost after iteration 263: 0.679075
# Cost after iteration 264: 0.677181
# Cost after iteration 265: 0.675134
# Cost after iteration 266: 0.672943
# Cost after iteration 267: 0.670625
# Cost after iteration 268: 0.668194
# Cost after iteration 269: 0.665670
# Cost after iteration 270: 0.663073
# Cost after iteration 271: 0.660421
# Cost after iteration 272: 0.657733
# Cost after iteration 273: 0.655027
# Cost after iteration 274: 0.652318
# Cost after iteration 275: 0.649621
# Cost after iteration 276: 0.646947
# Cost after iteration 277: 0.644307
# Cost after iteration 278: 0.641710
# Cost after iteration 279: 0.639161
# Cost after iteration 280: 0.636665
# Cost after iteration 281: 0.634225
# Cost after iteration 282: 0.631842
# Cost after iteration 283: 0.629517
# Cost after iteration 284: 0.627249
# Cost after iteration 285: 0.625036
# Cost after iteration 286: 0.622874
# Cost after iteration 287: 0.620759
# Cost after iteration 288: 0.618687
# Cost after iteration 289: 0.616652
# Cost after iteration 290: 0.614645
# Cost after iteration 291: 0.612659
# Cost after iteration 292: 0.610684
# Cost after iteration 293: 0.608708
# Cost after iteration 294: 0.606716
# Cost after iteration 295: 0.604689
# Cost after iteration 296: 0.602606
# Cost after iteration 297: 0.600438
# Cost after iteration 298: 0.598153
# Cost after iteration 299: 0.595716
# Cost after iteration 300: 0.593086
# Cost after iteration 301: 0.590224
# Cost after iteration 302: 0.587092
# Cost after iteration 303: 0.583654
# Cost after iteration 304: 0.579882
# Cost after iteration 305: 0.575759
# Cost after iteration 306: 0.571277
# Cost after iteration 307: 0.566444
# Cost after iteration 308: 0.561279
# Cost after iteration 309: 0.555812
# Cost after iteration 310: 0.550082
# Cost after iteration 311: 0.544130
# Cost after iteration 312: 0.538003
# Cost after iteration 313: 0.531746
# Cost after iteration 314: 0.525401
# Cost after iteration 315: 0.519007
# Cost after iteration 316: 0.512599
# Cost after iteration 317: 0.506208
# Cost after iteration 318: 0.499859
# Cost after iteration 319: 0.493576
# Cost after iteration 320: 0.487375
# Cost after iteration 321: 0.481273
# Cost after iteration 322: 0.475281
# Cost after iteration 323: 0.469408
# Cost after iteration 324: 0.463661
# Cost after iteration 325: 0.458046
# Cost after iteration 326: 0.452567
# Cost after iteration 327: 0.447224
# Cost after iteration 328: 0.442021
# Cost after iteration 329: 0.436956
# Cost after iteration 330: 0.432028
# Cost after iteration 331: 0.427238
# Cost after iteration 332: 0.422582
# Cost after iteration 333: 0.418059
# Cost after iteration 334: 0.413665
# Cost after iteration 335: 0.409398
# Cost after iteration 336: 0.405255
# Cost after iteration 337: 0.401232
# Cost after iteration 338: 0.397327
# Cost after iteration 339: 0.393536
# Cost after iteration 340: 0.389855
# Cost after iteration 341: 0.386281
# Cost after iteration 342: 0.382810
# Cost after iteration 343: 0.379439
# Cost after iteration 344: 0.376166
# Cost after iteration 345: 0.372986
# Cost after iteration 346: 0.369896
# Cost after iteration 347: 0.366893
# Cost after iteration 348: 0.363974
# Cost after iteration 349: 0.361137
# Cost after iteration 350: 0.358377
# Cost after iteration 351: 0.355694
# Cost after iteration 352: 0.353082
# Cost after iteration 353: 0.350541
# Cost after iteration 354: 0.348068
# Cost after iteration 355: 0.345659
# Cost after iteration 356: 0.343314
# Cost after iteration 357: 0.341029
# Cost after iteration 358: 0.338802
# Cost after iteration 359: 0.336631
# Cost after iteration 360: 0.334515
# Cost after iteration 361: 0.332450
# Cost after iteration 362: 0.330437
# Cost after iteration 363: 0.328471
# Cost after iteration 364: 0.326552
# Cost after iteration 365: 0.324679
# Cost after iteration 366: 0.322849
# Cost after iteration 367: 0.321060
# Cost after iteration 368: 0.319313
# Cost after iteration 369: 0.317604
# Cost after iteration 370: 0.315933
# Cost after iteration 371: 0.314298
# Cost after iteration 372: 0.312699
# Cost after iteration 373: 0.311133
# Cost after iteration 374: 0.309600
# Cost after iteration 375: 0.308098
# Cost after iteration 376: 0.306627
# Cost after iteration 377: 0.305186
# Cost after iteration 378: 0.303772
# Cost after iteration 379: 0.302387
# Cost after iteration 380: 0.301027
# Cost after iteration 381: 0.299694
# Cost after iteration 382: 0.298385
# Cost after iteration 383: 0.297100
# Cost after iteration 384: 0.295839
# Cost after iteration 385: 0.294600
# Cost after iteration 386: 0.293382
# Cost after iteration 387: 0.292186
# Cost after iteration 388: 0.291009
# Cost after iteration 389: 0.289853
# Cost after iteration 390: 0.288716
# Cost after iteration 391: 0.287596
# Cost after iteration 392: 0.286495
# Cost after iteration 393: 0.285411
# Cost after iteration 394: 0.284344
# Cost after iteration 395: 0.283293
# Cost after iteration 396: 0.282258
# Cost after iteration 397: 0.281238
# Cost after iteration 398: 0.280233
# Cost after iteration 399: 0.279242
# Cost after iteration 400: 0.278265
# Cost after iteration 401: 0.277302
# Cost after iteration 402: 0.276352
# Cost after iteration 403: 0.275414
# Cost after iteration 404: 0.274489
# Cost after iteration 405: 0.273575
# Cost after iteration 406: 0.272674
# Cost after iteration 407: 0.271784
# Cost after iteration 408: 0.270904
# Cost after iteration 409: 0.270036
# Cost after iteration 410: 0.269177
# Cost after iteration 411: 0.268329
# Cost after iteration 412: 0.267491
# Cost after iteration 413: 0.266662
# Cost after iteration 414: 0.265843
# Cost after iteration 415: 0.265033
# Cost after iteration 416: 0.264231
# Cost after iteration 417: 0.263439
# Cost after iteration 418: 0.262654
# Cost after iteration 419: 0.261878
# Cost after iteration 420: 0.261110
# Cost after iteration 421: 0.260350
# Cost after iteration 422: 0.259597
# Cost after iteration 423: 0.258852
# Cost after iteration 424: 0.258114
# Cost after iteration 425: 0.257383
# Cost after iteration 426: 0.256659
# Cost after iteration 427: 0.255942
# Cost after iteration 428: 0.255232
# Cost after iteration 429: 0.254528
# Cost after iteration 430: 0.253831
# Cost after iteration 431: 0.253139
# Cost after iteration 432: 0.252455
# Cost after iteration 433: 0.251776
# Cost after iteration 434: 0.251103
# Cost after iteration 435: 0.250436
# Cost after iteration 436: 0.249774
# Cost after iteration 437: 0.249119
# Cost after iteration 438: 0.248469
# Cost after iteration 439: 0.247824
# Cost after iteration 440: 0.247185
# Cost after iteration 441: 0.246551
# Cost after iteration 442: 0.245922
# Cost after iteration 443: 0.245299
# Cost after iteration 444: 0.244681
# Cost after iteration 445: 0.244067
# Cost after iteration 446: 0.243459
# Cost after iteration 447: 0.242856
# Cost after iteration 448: 0.242257
# Cost after iteration 449: 0.241664
# Cost after iteration 450: 0.241075
# Cost after iteration 451: 0.240491
# Cost after iteration 452: 0.239912
# Cost after iteration 453: 0.239337
# Cost after iteration 454: 0.238767
# Cost after iteration 455: 0.238202
# Cost after iteration 456: 0.237641
# Cost after iteration 457: 0.237085
# Cost after iteration 458: 0.236533
# Cost after iteration 459: 0.235986
# Cost after iteration 460: 0.235443
# Cost after iteration 461: 0.234905
# Cost after iteration 462: 0.234371
# Cost after iteration 463: 0.233842
# Cost after iteration 464: 0.233317
# Cost after iteration 465: 0.232796
# Cost after iteration 466: 0.232280
# Cost after iteration 467: 0.231768
# Cost after iteration 468: 0.231260
# Cost after iteration 469: 0.230757
# Cost after iteration 470: 0.230258
# Cost after iteration 471: 0.229763
# Cost after iteration 472: 0.229273
# Cost after iteration 473: 0.228787
# Cost after iteration 474: 0.228305
# Cost after iteration 475: 0.227827
# Cost after iteration 476: 0.227354
# Cost after iteration 477: 0.226885
# Cost after iteration 478: 0.226420
# Cost after iteration 479: 0.225959
# Cost after iteration 480: 0.225502
# Cost after iteration 481: 0.225050
# Cost after iteration 482: 0.224602
# Cost after iteration 483: 0.224158
# Cost after iteration 484: 0.223718
# Cost after iteration 485: 0.223282
# Cost after iteration 486: 0.222850
# Cost after iteration 487: 0.222422
# Cost after iteration 488: 0.221999
# Cost after iteration 489: 0.221579
# Cost after iteration 490: 0.221164
# Cost after iteration 491: 0.220753
# Cost after iteration 492: 0.220345
# Cost after iteration 493: 0.219942
# Cost after iteration 494: 0.219542
# Cost after iteration 495: 0.219147
# Cost after iteration 496: 0.218755
# Cost after iteration 497: 0.218367
# Cost after iteration 498: 0.217984
# Cost after iteration 499: 0.217604
# Cost after iteration 500: 0.217228
# Cost after iteration 501: 0.216856
# Cost after iteration 502: 0.216487
# Cost after iteration 503: 0.216123
# Cost after iteration 504: 0.215762
# Cost after iteration 505: 0.215405
# Cost after iteration 506: 0.215051
# Cost after iteration 507: 0.214701
# Cost after iteration 508: 0.214355
# Cost after iteration 509: 0.214013
# Cost after iteration 510: 0.213674
# Cost after iteration 511: 0.213338
# Cost after iteration 512: 0.213007
# Cost after iteration 513: 0.212678
# Cost after iteration 514: 0.212353
# Cost after iteration 515: 0.212032
# Cost after iteration 516: 0.211714
# Cost after iteration 517: 0.211400
# Cost after iteration 518: 0.211088
# Cost after iteration 519: 0.210780
# Cost after iteration 520: 0.210476
# Cost after iteration 521: 0.210175
# Cost after iteration 522: 0.209877
# Cost after iteration 523: 0.209584
# Cost after iteration 524: 0.209299
# Cost after iteration 525: 0.209040
# Cost after iteration 526: 0.208876
# Cost after iteration 527: 0.209103
# Cost after iteration 528: 0.210997
# Cost after iteration 529: 0.220308
# Cost after iteration 530: 0.265580
# Cost after iteration 531: 0.495220
# Cost after iteration 532: 0.862243
# Cost after iteration 533: 1.306689
# Cost after iteration 534: 0.252440
# Cost after iteration 535: 0.230642
# Cost after iteration 536: 0.226139
# Cost after iteration 537: 0.223902
# Cost after iteration 538: 0.222530
# Cost after iteration 539: 0.221382
# Cost after iteration 540: 0.220370
# Cost after iteration 541: 0.219448
# Cost after iteration 542: 0.218605
# Cost after iteration 543: 0.217825
# Cost after iteration 544: 0.217101
# Cost after iteration 545: 0.216424
# Cost after iteration 546: 0.215789
# Cost after iteration 547: 0.215189
# Cost after iteration 548: 0.214621
# Cost after iteration 549: 0.214081
# Cost after iteration 550: 0.213567
# Cost after iteration 551: 0.213074
# Cost after iteration 552: 0.212603
# Cost after iteration 553: 0.212151
# Cost after iteration 554: 0.211719
# Cost after iteration 555: 0.211304
# Cost after iteration 556: 0.210914
# Cost after iteration 557: 0.210542
# Cost after iteration 558: 0.210206
# Cost after iteration 559: 0.209895
# Cost after iteration 560: 0.209651
# Cost after iteration 561: 0.209448
# Cost after iteration 562: 0.209394
# Cost after iteration 563: 0.209417
# Cost after iteration 564: 0.209816
# Cost after iteration 565: 0.210351
# Cost after iteration 566: 0.211952
# Cost after iteration 567: 0.213680
# Cost after iteration 568: 0.218713
# Cost after iteration 569: 0.222748
# Cost after iteration 570: 0.236954
# Cost after iteration 571: 0.240578
# Cost after iteration 572: 0.270549
# Cost after iteration 573: 0.258939
# Cost after iteration 574: 0.296759
# Cost after iteration 575: 0.265412
# Cost after iteration 576: 0.293501
# Cost after iteration 577: 0.276011
# Cost after iteration 578: 0.313730
# Cost after iteration 579: 0.340571
# Cost after iteration 580: 0.420170
# Cost after iteration 581: 0.402128
# Cost after iteration 582: 0.387130
# Cost after iteration 583: 0.303160
# Cost after iteration 584: 0.262090
# Cost after iteration 585: 0.234702
# Cost after iteration 586: 0.223311
# Cost after iteration 587: 0.217774
# Cost after iteration 588: 0.215773
# Cost after iteration 589: 0.213836
# Cost after iteration 590: 0.212817
# Cost after iteration 591: 0.211816
# Cost after iteration 592: 0.211129
# Cost after iteration 593: 0.210471
# Cost after iteration 594: 0.209937
# Cost after iteration 595: 0.209422
# Cost after iteration 596: 0.208962
# Cost after iteration 597: 0.208514
# Cost after iteration 598: 0.208095
# Cost after iteration 599: 0.207684
# Cost after iteration 600: 0.207290
# Cost after iteration 601: 0.206902
# Cost after iteration 602: 0.206526
# Cost after iteration 603: 0.206155
# Cost after iteration 604: 0.205794
# Cost after iteration 605: 0.205438
# Cost after iteration 606: 0.205089
# Cost after iteration 607: 0.204746
# Cost after iteration 608: 0.204411
# Cost after iteration 609: 0.204080
# Cost after iteration 610: 0.203757
# Cost after iteration 611: 0.203440
# Cost after iteration 612: 0.203131
# Cost after iteration 613: 0.202829
# Cost after iteration 614: 0.202538
# Cost after iteration 615: 0.202253
# Cost after iteration 616: 0.201985
# Cost after iteration 617: 0.201725
# Cost after iteration 618: 0.201492
# Cost after iteration 619: 0.201273
# Cost after iteration 620: 0.201103
# Cost after iteration 621: 0.200956
# Cost after iteration 622: 0.200912
# Cost after iteration 623: 0.200913
# Cost after iteration 624: 0.201155
# Cost after iteration 625: 0.201487
# Cost after iteration 626: 0.202453
# Cost after iteration 627: 0.203578
# Cost after iteration 628: 0.206565
# Cost after iteration 629: 0.209643
# Cost after iteration 630: 0.218609
# Cost after iteration 631: 0.225453
# Cost after iteration 632: 0.250078
# Cost after iteration 633: 0.256855
# Cost after iteration 634: 0.312268
# Cost after iteration 635: 0.323767
# Cost after iteration 636: 0.470940
# Cost after iteration 637: 0.516601
# Cost after iteration 638: 0.706940
# Cost after iteration 639: 0.320374
# Cost after iteration 640: 0.274953
# Cost after iteration 641: 0.228872
# Cost after iteration 642: 0.216864
# Cost after iteration 643: 0.211628
# Cost after iteration 644: 0.209610
# Cost after iteration 645: 0.208316
# Cost after iteration 646: 0.207518
# Cost after iteration 647: 0.206878
# Cost after iteration 648: 0.206343
# Cost after iteration 649: 0.205856
# Cost after iteration 650: 0.205403
# Cost after iteration 651: 0.204971
# Cost after iteration 652: 0.204555
# Cost after iteration 653: 0.204153
# Cost after iteration 654: 0.203763
# Cost after iteration 655: 0.203383
# Cost after iteration 656: 0.203012
# Cost after iteration 657: 0.202650
# Cost after iteration 658: 0.202297
# Cost after iteration 659: 0.201951
# Cost after iteration 660: 0.201613
# Cost after iteration 661: 0.201283
# Cost after iteration 662: 0.200959
# Cost after iteration 663: 0.200642
# Cost after iteration 664: 0.200331
# Cost after iteration 665: 0.200026
# Cost after iteration 666: 0.199728
# Cost after iteration 667: 0.199436
# Cost after iteration 668: 0.199150
# Cost after iteration 669: 0.198869
# Cost after iteration 670: 0.198594
# Cost after iteration 671: 0.198325
# Cost after iteration 672: 0.198060
# Cost after iteration 673: 0.197802
# Cost after iteration 674: 0.197548
# Cost after iteration 675: 0.197300
# Cost after iteration 676: 0.197057
# Cost after iteration 677: 0.196819
# Cost after iteration 678: 0.196585
# Cost after iteration 679: 0.196357
# Cost after iteration 680: 0.196133
# Cost after iteration 681: 0.195914
# Cost after iteration 682: 0.195700
# Cost after iteration 683: 0.195490
# Cost after iteration 684: 0.195285
# Cost after iteration 685: 0.195084
# Cost after iteration 686: 0.194887
# Cost after iteration 687: 0.194695
# Cost after iteration 688: 0.194507
# Cost after iteration 689: 0.194323
# Cost after iteration 690: 0.194143
# Cost after iteration 691: 0.193967
# Cost after iteration 692: 0.193796
# Cost after iteration 693: 0.193629
# Cost after iteration 694: 0.193468
# Cost after iteration 695: 0.193313
# Cost after iteration 696: 0.193167
# Cost after iteration 697: 0.193035
# Cost after iteration 698: 0.192927
# Cost after iteration 699: 0.192862
# Cost after iteration 700: 0.192887
# Cost after iteration 701: 0.193083
# Cost after iteration 702: 0.193666
# Cost after iteration 703: 0.195020
# Cost after iteration 704: 0.198322
# Cost after iteration 705: 0.205642
# Cost after iteration 706: 0.225366
# Cost after iteration 707: 0.274940
# Cost after iteration 708: 0.437638
# Cost after iteration 709: 0.614927
# Cost after iteration 710: 1.191214
# Cost after iteration 711: 0.339963
# Cost after iteration 712: 0.367926
# Cost after iteration 713: 0.216212
# Cost after iteration 714: 0.211598
# Cost after iteration 715: 0.208938
# Cost after iteration 716: 0.207588
# Cost after iteration 717: 0.206590
# Cost after iteration 718: 0.205767
# Cost after iteration 719: 0.205030
# Cost after iteration 720: 0.204350
# Cost after iteration 721: 0.203715
# Cost after iteration 722: 0.203117
# Cost after iteration 723: 0.202553
# Cost after iteration 724: 0.202018
# Cost after iteration 725: 0.201511
# Cost after iteration 726: 0.201028
# Cost after iteration 727: 0.200569
# Cost after iteration 728: 0.200130
# Cost after iteration 729: 0.199711
# Cost after iteration 730: 0.199310
# Cost after iteration 731: 0.198926
# Cost after iteration 732: 0.198558
# Cost after iteration 733: 0.198203
# Cost after iteration 734: 0.197863
# Cost after iteration 735: 0.197535
# Cost after iteration 736: 0.197219
# Cost after iteration 737: 0.196914
# Cost after iteration 738: 0.196619
# Cost after iteration 739: 0.196334
# Cost after iteration 740: 0.196059
# Cost after iteration 741: 0.195793
# Cost after iteration 742: 0.195535
# Cost after iteration 743: 0.195284
# Cost after iteration 744: 0.195042
# Cost after iteration 745: 0.194807
# Cost after iteration 746: 0.194578
# Cost after iteration 747: 0.194356
# Cost after iteration 748: 0.194141
# Cost after iteration 749: 0.193932
# Cost after iteration 750: 0.193728
# Cost after iteration 751: 0.193530
# Cost after iteration 752: 0.193338
# Cost after iteration 753: 0.193150
# Cost after iteration 754: 0.192968
# Cost after iteration 755: 0.192791
# Cost after iteration 756: 0.192618
# Cost after iteration 757: 0.192450
# Cost after iteration 758: 0.192286
# Cost after iteration 759: 0.192126
# Cost after iteration 760: 0.191971
# Cost after iteration 761: 0.191819
# Cost after iteration 762: 0.191672
# Cost after iteration 763: 0.191528
# Cost after iteration 764: 0.191387
# Cost after iteration 765: 0.191250
# Cost after iteration 766: 0.191117
# Cost after iteration 767: 0.190986
# Cost after iteration 768: 0.190859
# Cost after iteration 769: 0.190735
# Cost after iteration 770: 0.190614
# Cost after iteration 771: 0.190496
# Cost after iteration 772: 0.190381
# Cost after iteration 773: 0.190268
# Cost after iteration 774: 0.190158
# Cost after iteration 775: 0.190050
# Cost after iteration 776: 0.189945
# Cost after iteration 777: 0.189842
# Cost after iteration 778: 0.189742
# Cost after iteration 779: 0.189644
# Cost after iteration 780: 0.189549
# Cost after iteration 781: 0.189456
# Cost after iteration 782: 0.189367
# Cost after iteration 783: 0.189283
# Cost after iteration 784: 0.189209
# Cost after iteration 785: 0.189152
# Cost after iteration 786: 0.189132
# Cost after iteration 787: 0.189195
# Cost after iteration 788: 0.189449
# Cost after iteration 789: 0.190125
# Cost after iteration 790: 0.191891
# Cost after iteration 791: 0.196063
# Cost after iteration 792: 0.207592
# Cost after iteration 793: 0.237189
# Cost after iteration 794: 0.344240
# Cost after iteration 795: 0.528968
# Cost after iteration 796: 0.852605
# Cost after iteration 797: 0.363314
# Cost after iteration 798: 0.568018
# Cost after iteration 799: 0.241111
# Cost after iteration 800: 0.231399
# Cost after iteration 801: 0.208417
# Cost after iteration 802: 0.204333
# Cost after iteration 803: 0.201290
# Cost after iteration 804: 0.199836
# Cost after iteration 805: 0.198802
# Cost after iteration 806: 0.198089
# Cost after iteration 807: 0.197505
# Cost after iteration 808: 0.197009
# Cost after iteration 809: 0.196562
# Cost after iteration 810: 0.196152
# Cost after iteration 811: 0.195768
# Cost after iteration 812: 0.195408
# Cost after iteration 813: 0.195067
# Cost after iteration 814: 0.194743
# Cost after iteration 815: 0.194435
# Cost after iteration 816: 0.194142
# Cost after iteration 817: 0.193862
# Cost after iteration 818: 0.193594
# Cost after iteration 819: 0.193338
# Cost after iteration 820: 0.193092
# Cost after iteration 821: 0.192857
# Cost after iteration 822: 0.192632
# Cost after iteration 823: 0.192415
# Cost after iteration 824: 0.192207
# Cost after iteration 825: 0.192006
# Cost after iteration 826: 0.191814
# Cost after iteration 827: 0.191628
# Cost after iteration 828: 0.191449
# Cost after iteration 829: 0.191277
# Cost after iteration 830: 0.191110
# Cost after iteration 831: 0.190950
# Cost after iteration 832: 0.190794
# Cost after iteration 833: 0.190644
# Cost after iteration 834: 0.190499
# Cost after iteration 835: 0.190359
# Cost after iteration 836: 0.190223
# Cost after iteration 837: 0.190092
# Cost after iteration 838: 0.189964
# Cost after iteration 839: 0.189841
# Cost after iteration 840: 0.189721
# Cost after iteration 841: 0.189605
# Cost after iteration 842: 0.189493
# Cost after iteration 843: 0.189384
# Cost after iteration 844: 0.189279
# Cost after iteration 845: 0.189178
# Cost after iteration 846: 0.189082
# Cost after iteration 847: 0.188991
# Cost after iteration 848: 0.188907
# Cost after iteration 849: 0.188833
# Cost after iteration 850: 0.188776
# Cost after iteration 851: 0.188744
# Cost after iteration 852: 0.188758
# Cost after iteration 853: 0.188850
# Cost after iteration 854: 0.189097
# Cost after iteration 855: 0.189601
# Cost after iteration 856: 0.190684
# Cost after iteration 857: 0.192699
# Cost after iteration 858: 0.197177
# Cost after iteration 859: 0.205644
# Cost after iteration 860: 0.227937
# Cost after iteration 861: 0.274823
# Cost after iteration 862: 0.421417
# Cost after iteration 863: 0.509105
# Cost after iteration 864: 0.682842
# Cost after iteration 865: 0.361496
# Cost after iteration 866: 0.458843
# Cost after iteration 867: 0.268811
# Cost after iteration 868: 0.260714
# Cost after iteration 869: 0.212008
# Cost after iteration 870: 0.207064
# Cost after iteration 871: 0.201775
# Cost after iteration 872: 0.199810
# Cost after iteration 873: 0.198289
# Cost after iteration 874: 0.197441
# Cost after iteration 875: 0.196786
# Cost after iteration 876: 0.196293
# Cost after iteration 877: 0.195867
# Cost after iteration 878: 0.195492
# Cost after iteration 879: 0.195146
# Cost after iteration 880: 0.194822
# Cost after iteration 881: 0.194515
# Cost after iteration 882: 0.194224
# Cost after iteration 883: 0.193944
# Cost after iteration 884: 0.193677
# Cost after iteration 885: 0.193420
# Cost after iteration 886: 0.193172
# Cost after iteration 887: 0.192934
# Cost after iteration 888: 0.192705
# Cost after iteration 889: 0.192484
# Cost after iteration 890: 0.192271
# Cost after iteration 891: 0.192065
# Cost after iteration 892: 0.191867
# Cost after iteration 893: 0.191675
# Cost after iteration 894: 0.191490
# Cost after iteration 895: 0.191311
# Cost after iteration 896: 0.191138
# Cost after iteration 897: 0.190970
# Cost after iteration 898: 0.190808
# Cost after iteration 899: 0.190651
# Cost after iteration 900: 0.190499
# Cost after iteration 901: 0.190352
# Cost after iteration 902: 0.190209
# Cost after iteration 903: 0.190071
# Cost after iteration 904: 0.189937
# Cost after iteration 905: 0.189807
# Cost after iteration 906: 0.189681
# Cost after iteration 907: 0.189559
# Cost after iteration 908: 0.189441
# Cost after iteration 909: 0.189326
# Cost after iteration 910: 0.189214
# Cost after iteration 911: 0.189106
# Cost after iteration 912: 0.189000
# Cost after iteration 913: 0.188898
# Cost after iteration 914: 0.188799
# Cost after iteration 915: 0.188702
# Cost after iteration 916: 0.188608
# Cost after iteration 917: 0.188517
# Cost after iteration 918: 0.188428
# Cost after iteration 919: 0.188342
# Cost after iteration 920: 0.188258
# Cost after iteration 921: 0.188177
# Cost after iteration 922: 0.188098
# Cost after iteration 923: 0.188022
# Cost after iteration 924: 0.187949
# Cost after iteration 925: 0.187878
# Cost after iteration 926: 0.187812
# Cost after iteration 927: 0.187750
# Cost after iteration 928: 0.187695
# Cost after iteration 929: 0.187651
# Cost after iteration 930: 0.187623
# Cost after iteration 931: 0.187619
# Cost after iteration 932: 0.187662
# Cost after iteration 933: 0.187771
# Cost after iteration 934: 0.188032
# Cost after iteration 935: 0.188484
# Cost after iteration 936: 0.189461
# Cost after iteration 937: 0.191024
# Cost after iteration 938: 0.194631
# Cost after iteration 939: 0.200133
# Cost after iteration 940: 0.214709
# Cost after iteration 941: 0.235107
# Cost after iteration 942: 0.301143
# Cost after iteration 943: 0.366854
# Cost after iteration 944: 0.705018
# Cost after iteration 945: 0.592006
# Cost after iteration 946: 0.974930
# Cost after iteration 947: 0.242286
# Cost after iteration 948: 0.216017
# Cost after iteration 949: 0.205214
# Cost after iteration 950: 0.202420
# Cost after iteration 951: 0.201211
# Cost after iteration 952: 0.200445
# Cost after iteration 953: 0.199810
# Cost after iteration 954: 0.199234
# Cost after iteration 955: 0.198696
# Cost after iteration 956: 0.198188
# Cost after iteration 957: 0.197708
# Cost after iteration 958: 0.197253
# Cost after iteration 959: 0.196822
# Cost after iteration 960: 0.196412
# Cost after iteration 961: 0.196022
# Cost after iteration 962: 0.195652
# Cost after iteration 963: 0.195299
# Cost after iteration 964: 0.194962
# Cost after iteration 965: 0.194641
# Cost after iteration 966: 0.194335
# Cost after iteration 967: 0.194043
# Cost after iteration 968: 0.193763
# Cost after iteration 969: 0.193496
# Cost after iteration 970: 0.193240
# Cost after iteration 971: 0.192994
# Cost after iteration 972: 0.192759
# Cost after iteration 973: 0.192534
# Cost after iteration 974: 0.192318
# Cost after iteration 975: 0.192110
# Cost after iteration 976: 0.191911
# Cost after iteration 977: 0.191719
# Cost after iteration 978: 0.191534
# Cost after iteration 979: 0.191356
# Cost after iteration 980: 0.191185
# Cost after iteration 981: 0.191020
# Cost after iteration 982: 0.190861
# Cost after iteration 983: 0.190708
# Cost after iteration 984: 0.190560
# Cost after iteration 985: 0.190417
# Cost after iteration 986: 0.190279
# Cost after iteration 987: 0.190145
# Cost after iteration 988: 0.190016
# Cost after iteration 989: 0.189891
# Cost after iteration 990: 0.189770
# Cost after iteration 991: 0.189653
# Cost after iteration 992: 0.189540
# Cost after iteration 993: 0.189430
# Cost after iteration 994: 0.189324
# Cost after iteration 995: 0.189220
# Cost after iteration 996: 0.189120
# Cost after iteration 997: 0.189023
# Cost after iteration 998: 0.188929
# Cost after iteration 999: 0.188837
# Cost after iteration 1000: 0.188748
# Cost after iteration 1001: 0.188661
# Cost after iteration 1002: 0.188577
# Cost after iteration 1003: 0.188495
# Cost after iteration 1004: 0.188415
# Cost after iteration 1005: 0.188337
# Cost after iteration 1006: 0.188262
# Cost after iteration 1007: 0.188188
# Cost after iteration 1008: 0.188116
# Cost after iteration 1009: 0.188047
# Cost after iteration 1010: 0.187978
# Cost after iteration 1011: 0.187912
# Cost after iteration 1012: 0.187847
# Cost after iteration 1013: 0.187784
# Cost after iteration 1014: 0.187722
# Cost after iteration 1015: 0.187661
# Cost after iteration 1016: 0.187602
# Cost after iteration 1017: 0.187545
# Cost after iteration 1018: 0.187488
# Cost after iteration 1019: 0.187433
# Cost after iteration 1020: 0.187379
# Cost after iteration 1021: 0.187326
# Cost after iteration 1022: 0.187275
# Cost after iteration 1023: 0.187224
# Cost after iteration 1024: 0.187175
# Cost after iteration 1025: 0.187126
# Cost after iteration 1026: 0.187079
# Cost after iteration 1027: 0.187032
# Cost after iteration 1028: 0.186986
# Cost after iteration 1029: 0.186941
# Cost after iteration 1030: 0.186898
# Cost after iteration 1031: 0.186854
# Cost after iteration 1032: 0.186812
# Cost after iteration 1033: 0.186771
# Cost after iteration 1034: 0.186730
# Cost after iteration 1035: 0.186690
# Cost after iteration 1036: 0.186650
# Cost after iteration 1037: 0.186612
# Cost after iteration 1038: 0.186574
# Cost after iteration 1039: 0.186536
# Cost after iteration 1040: 0.186499
# Cost after iteration 1041: 0.186463
# Cost after iteration 1042: 0.186428
# Cost after iteration 1043: 0.186393
# Cost after iteration 1044: 0.186358
# Cost after iteration 1045: 0.186324
# Cost after iteration 1046: 0.186291
# Cost after iteration 1047: 0.186258
# Cost after iteration 1048: 0.186225
# Cost after iteration 1049: 0.186193
# Cost after iteration 1050: 0.186162
# Cost after iteration 1051: 0.186131
# Cost after iteration 1052: 0.186100
# Cost after iteration 1053: 0.186070
# Cost after iteration 1054: 0.186041
# Cost after iteration 1055: 0.186013
# Cost after iteration 1056: 0.185986
# Cost after iteration 1057: 0.185961
# Cost after iteration 1058: 0.185941
# Cost after iteration 1059: 0.185931
# Cost after iteration 1060: 0.185941
# Cost after iteration 1061: 0.185992
# Cost after iteration 1062: 0.186136
# Cost after iteration 1063: 0.186470
# Cost after iteration 1064: 0.187256
# Cost after iteration 1065: 0.188938
# Cost after iteration 1066: 0.193019
# Cost after iteration 1067: 0.201565
# Cost after iteration 1068: 0.225840
# Cost after iteration 1069: 0.279708
# Cost after iteration 1070: 0.492129
# Cost after iteration 1071: 0.725056
# Cost after iteration 1072: 1.800950
# Cost after iteration 1073: 0.955109
# Cost after iteration 1074: 0.274019
# Cost after iteration 1075: 0.235233
# Cost after iteration 1076: 0.228798
# Cost after iteration 1077: 0.224488
# Cost after iteration 1078: 0.220896
# Cost after iteration 1079: 0.217830
# Cost after iteration 1080: 0.215181
# Cost after iteration 1081: 0.212868
# Cost after iteration 1082: 0.210832
# Cost after iteration 1083: 0.209025
# Cost after iteration 1084: 0.207411
# Cost after iteration 1085: 0.205960
# Cost after iteration 1086: 0.204649
# Cost after iteration 1087: 0.203460
# Cost after iteration 1088: 0.202376
# Cost after iteration 1089: 0.201385
# Cost after iteration 1090: 0.200475
# Cost after iteration 1091: 0.199637
# Cost after iteration 1092: 0.198865
# Cost after iteration 1093: 0.198150
# Cost after iteration 1094: 0.197487
# Cost after iteration 1095: 0.196872
# Cost after iteration 1096: 0.196300
# Cost after iteration 1097: 0.195766
# Cost after iteration 1098: 0.195268
# Cost after iteration 1099: 0.194803
# Cost after iteration 1100: 0.194368
# Cost after iteration 1101: 0.193960
# Cost after iteration 1102: 0.193577
# Cost after iteration 1103: 0.193218
# Cost after iteration 1104: 0.192881
# Cost after iteration 1105: 0.192563
# Cost after iteration 1106: 0.192264
# Cost after iteration 1107: 0.191983
# Cost after iteration 1108: 0.191717
# Cost after iteration 1109: 0.191466
# Cost after iteration 1110: 0.191229
# Cost after iteration 1111: 0.191005
# Cost after iteration 1112: 0.190793
# Cost after iteration 1113: 0.190592
# Cost after iteration 1114: 0.190402
# Cost after iteration 1115: 0.190221
# Cost after iteration 1116: 0.190049
# Cost after iteration 1117: 0.189887
# Cost after iteration 1118: 0.189732
# Cost after iteration 1119: 0.189584
# Cost after iteration 1120: 0.189444
# Cost after iteration 1121: 0.189310
# Cost after iteration 1122: 0.189182
# Cost after iteration 1123: 0.189061
# Cost after iteration 1124: 0.188944
# Cost after iteration 1125: 0.188833
# Cost after iteration 1126: 0.188726
# Cost after iteration 1127: 0.188624
# Cost after iteration 1128: 0.188527
# Cost after iteration 1129: 0.188433
# Cost after iteration 1130: 0.188343
# Cost after iteration 1131: 0.188257
# Cost after iteration 1132: 0.188174
# Cost after iteration 1133: 0.188094
# Cost after iteration 1134: 0.188017
# Cost after iteration 1135: 0.187944
# Cost after iteration 1136: 0.187872
# Cost after iteration 1137: 0.187804
# Cost after iteration 1138: 0.187737
# Cost after iteration 1139: 0.187673
# Cost after iteration 1140: 0.187611
# Cost after iteration 1141: 0.187551
# Cost after iteration 1142: 0.187494
# Cost after iteration 1143: 0.187437
# Cost after iteration 1144: 0.187383
# Cost after iteration 1145: 0.187330
# Cost after iteration 1146: 0.187279
# Cost after iteration 1147: 0.187230
# Cost after iteration 1148: 0.187182
# Cost after iteration 1149: 0.187135
# Cost after iteration 1150: 0.187089
# Cost after iteration 1151: 0.187045
# Cost after iteration 1152: 0.187002
# Cost after iteration 1153: 0.186960
# Cost after iteration 1154: 0.186919
# Cost after iteration 1155: 0.186879
# Cost after iteration 1156: 0.186840
# Cost after iteration 1157: 0.186802
# Cost after iteration 1158: 0.186765
# Cost after iteration 1159: 0.186729
# Cost after iteration 1160: 0.186693
# Cost after iteration 1161: 0.186659
# Cost after iteration 1162: 0.186625
# Cost after iteration 1163: 0.186592
# Cost after iteration 1164: 0.186559
# Cost after iteration 1165: 0.186527
# Cost after iteration 1166: 0.186496
# Cost after iteration 1167: 0.186465
# Cost after iteration 1168: 0.186435
# Cost after iteration 1169: 0.186406
# Cost after iteration 1170: 0.186377
# Cost after iteration 1171: 0.186348
# Cost after iteration 1172: 0.186320
# Cost after iteration 1173: 0.186293
# Cost after iteration 1174: 0.186266
# Cost after iteration 1175: 0.186239
# Cost after iteration 1176: 0.186213
# Cost after iteration 1177: 0.186188
# Cost after iteration 1178: 0.186162
# Cost after iteration 1179: 0.186137
# Cost after iteration 1180: 0.186113
# Cost after iteration 1181: 0.186088
# Cost after iteration 1182: 0.186065
# Cost after iteration 1183: 0.186041
# Cost after iteration 1184: 0.186018
# Cost after iteration 1185: 0.185995
# Cost after iteration 1186: 0.185972
# Cost after iteration 1187: 0.185950
# Cost after iteration 1188: 0.185928
# Cost after iteration 1189: 0.185906
# Cost after iteration 1190: 0.185884
# Cost after iteration 1191: 0.185863
# Cost after iteration 1192: 0.185842
# Cost after iteration 1193: 0.185821
# Cost after iteration 1194: 0.185801
# Cost after iteration 1195: 0.185780
# Cost after iteration 1196: 0.185760
# Cost after iteration 1197: 0.185740
# Cost after iteration 1198: 0.185721
# Cost after iteration 1199: 0.185701
# Cost after iteration 1200: 0.185682
# Cost after iteration 1201: 0.185663
# Cost after iteration 1202: 0.185644
# Cost after iteration 1203: 0.185626
# Cost after iteration 1204: 0.185608
# Cost after iteration 1205: 0.185592
# Cost after iteration 1206: 0.185579
# Cost after iteration 1207: 0.185574
# Cost after iteration 1208: 0.185586
# Cost after iteration 1209: 0.185640
# Cost after iteration 1210: 0.185786
# Cost after iteration 1211: 0.186186
# Cost after iteration 1212: 0.187101
# Cost after iteration 1213: 0.189685
# Cost after iteration 1214: 0.195220
# Cost after iteration 1215: 0.213507
# Cost after iteration 1216: 0.245598
# Cost after iteration 1217: 0.378525
# Cost after iteration 1218: 0.391016
# Cost after iteration 1219: 0.725946
# Cost after iteration 1220: 0.426267
# Cost after iteration 1221: 0.625463
# Cost after iteration 1222: 0.269596
# Cost after iteration 1223: 0.262414
# Cost after iteration 1224: 0.229197
# Cost after iteration 1225: 0.215737
# Cost after iteration 1226: 0.205160
# Cost after iteration 1227: 0.199444
# Cost after iteration 1228: 0.196326
# Cost after iteration 1229: 0.194707
# Cost after iteration 1230: 0.193778
# Cost after iteration 1231: 0.193187
# Cost after iteration 1232: 0.192744
# Cost after iteration 1233: 0.192380
# Cost after iteration 1234: 0.192059
# Cost after iteration 1235: 0.191768
# Cost after iteration 1236: 0.191498
# Cost after iteration 1237: 0.191245
# Cost after iteration 1238: 0.191008
# Cost after iteration 1239: 0.190784
# Cost after iteration 1240: 0.190573
# Cost after iteration 1241: 0.190373
# Cost after iteration 1242: 0.190183
# Cost after iteration 1243: 0.190003
# Cost after iteration 1244: 0.189833
# Cost after iteration 1245: 0.189671
# Cost after iteration 1246: 0.189518
# Cost after iteration 1247: 0.189372
# Cost after iteration 1248: 0.189233
# Cost after iteration 1249: 0.189100
# Cost after iteration 1250: 0.188974
# Cost after iteration 1251: 0.188854
# Cost after iteration 1252: 0.188739
# Cost after iteration 1253: 0.188630
# Cost after iteration 1254: 0.188525
# Cost after iteration 1255: 0.188425
# Cost after iteration 1256: 0.188329
# Cost after iteration 1257: 0.188237
# Cost after iteration 1258: 0.188149
# Cost after iteration 1259: 0.188065
# Cost after iteration 1260: 0.187984
# Cost after iteration 1261: 0.187906
# Cost after iteration 1262: 0.187831
# Cost after iteration 1263: 0.187759
# Cost after iteration 1264: 0.187690
# Cost after iteration 1265: 0.187623
# Cost after iteration 1266: 0.187559
# Cost after iteration 1267: 0.187496
# Cost after iteration 1268: 0.187436
# Cost after iteration 1269: 0.187378
# Cost after iteration 1270: 0.187322
# Cost after iteration 1271: 0.187268
# Cost after iteration 1272: 0.187215
# Cost after iteration 1273: 0.187164
# Cost after iteration 1274: 0.187114
# Cost after iteration 1275: 0.187066
# Cost after iteration 1276: 0.187020
# Cost after iteration 1277: 0.186974
# Cost after iteration 1278: 0.186930
# Cost after iteration 1279: 0.186887
# Cost after iteration 1280: 0.186845
# Cost after iteration 1281: 0.186805
# Cost after iteration 1282: 0.186765
# Cost after iteration 1283: 0.186727
# Cost after iteration 1284: 0.186689
# Cost after iteration 1285: 0.186653
# Cost after iteration 1286: 0.186617
# Cost after iteration 1287: 0.186583
# Cost after iteration 1288: 0.186550
# Cost after iteration 1289: 0.186519
# Cost after iteration 1290: 0.186490
# Cost after iteration 1291: 0.186463
# Cost after iteration 1292: 0.186440
# Cost after iteration 1293: 0.186423
# Cost after iteration 1294: 0.186414
# Cost after iteration 1295: 0.186420
# Cost after iteration 1296: 0.186445
# Cost after iteration 1297: 0.186508
# Cost after iteration 1298: 0.186623
# Cost after iteration 1299: 0.186841
# Cost after iteration 1300: 0.187202
# Cost after iteration 1301: 0.187865
# Cost after iteration 1302: 0.188923
# Cost after iteration 1303: 0.190941
# Cost after iteration 1304: 0.194083
# Cost after iteration 1305: 0.200704
# Cost after iteration 1306: 0.210902
# Cost after iteration 1307: 0.238162
# Cost after iteration 1308: 0.281398
# Cost after iteration 1309: 0.431500
# Cost after iteration 1310: 0.496763
# Cost after iteration 1311: 0.805374
# Cost after iteration 1312: 0.367531
# Cost after iteration 1313: 0.413583
# Cost after iteration 1314: 0.229681
# Cost after iteration 1315: 0.213130
# Cost after iteration 1316: 0.201181
# Cost after iteration 1317: 0.197607
# Cost after iteration 1318: 0.195769
# Cost after iteration 1319: 0.194911
# Cost after iteration 1320: 0.194355
# Cost after iteration 1321: 0.193941
# Cost after iteration 1322: 0.193585
# Cost after iteration 1323: 0.193263
# Cost after iteration 1324: 0.192964
# Cost after iteration 1325: 0.192681
# Cost after iteration 1326: 0.192413
# Cost after iteration 1327: 0.192159
# Cost after iteration 1328: 0.191916
# Cost after iteration 1329: 0.191686
# Cost after iteration 1330: 0.191466
# Cost after iteration 1331: 0.191256
# Cost after iteration 1332: 0.191056
# Cost after iteration 1333: 0.190865
# Cost after iteration 1334: 0.190683
# Cost after iteration 1335: 0.190509
# Cost after iteration 1336: 0.190342
# Cost after iteration 1337: 0.190183
# Cost after iteration 1338: 0.190030
# Cost after iteration 1339: 0.189884
# Cost after iteration 1340: 0.189745
# Cost after iteration 1341: 0.189611
# Cost after iteration 1342: 0.189482
# Cost after iteration 1343: 0.189359
# Cost after iteration 1344: 0.189240
# Cost after iteration 1345: 0.189127
# Cost after iteration 1346: 0.189018
# Cost after iteration 1347: 0.188913
# Cost after iteration 1348: 0.188812
# Cost after iteration 1349: 0.188714
# Cost after iteration 1350: 0.188621
# Cost after iteration 1351: 0.188531
# Cost after iteration 1352: 0.188444
# Cost after iteration 1353: 0.188360
# Cost after iteration 1354: 0.188279
# Cost after iteration 1355: 0.188201
# Cost after iteration 1356: 0.188126
# Cost after iteration 1357: 0.188053
# Cost after iteration 1358: 0.187983
# Cost after iteration 1359: 0.187915
# Cost after iteration 1360: 0.187849
# Cost after iteration 1361: 0.187785
# Cost after iteration 1362: 0.187723
# Cost after iteration 1363: 0.187664
# ...
# Cost after iteration 2560: 0.191816
# Cost after iteration 2561: 0.190882
# Cost after iteration 2562: 0.190110
# Cost after iteration 2563: 0.189669
# Cost after iteration 2564: 0.189287
# Cost after iteration 2565: 0.189056
# Cost after iteration 2566: 0.188839
# Cost after iteration 2567: 0.188699
# Cost after iteration 2568: 0.188558
# Cost after iteration 2569: 0.188461
# Cost after iteration 2570: 0.188358
# Cost after iteration 2571: 0.188284
# Cost after iteration 2572: 0.188204
# Cost after iteration 2573: 0.188144
# Cost after iteration 2574: 0.188078
# Cost after iteration 2575: 0.188027
# Cost after iteration 2576: 0.187971
# Cost after iteration 2577: 0.187929
# Cost after iteration 2578: 0.187881
# Cost after iteration 2579: 0.187846
# Cost after iteration 2580: 0.187805
# Cost after iteration 2581: 0.187778
# Cost after iteration 2582: 0.187744
# Cost after iteration 2583: 0.187727
# Cost after iteration 2584: 0.187701
# Cost after iteration 2585: 0.187697
# Cost after iteration 2586: 0.187682
# Cost after iteration 2587: 0.187697
# Cost after iteration 2588: 0.187697
# Cost after iteration 2589: 0.187744
# Cost after iteration 2590: 0.187767
# Cost after iteration 2591: 0.187865
# Cost after iteration 2592: 0.187926
# Cost after iteration 2593: 0.188118
# Cost after iteration 2594: 0.188244
# Cost after iteration 2595: 0.188614
# Cost after iteration 2596: 0.188856
# Cost after iteration 2597: 0.189583
# Cost after iteration 2598: 0.190048
# Cost after iteration 2599: 0.191542
# Cost after iteration 2600: 0.192465
# Cost after iteration 2601: 0.195726
# Cost after iteration 2602: 0.197624
# Cost after iteration 2603: 0.205075
# Cost after iteration 2604: 0.208295
# Cost after iteration 2605: 0.224522
# Cost after iteration 2606: 0.223506
# Cost after iteration 2607: 0.250213
# Cost after iteration 2608: 0.231712
# Cost after iteration 2609: 0.256338
# Cost after iteration 2610: 0.227542
# Cost after iteration 2611: 0.240374
# Cost after iteration 2612: 0.221352
# Cost after iteration 2613: 0.228469
# Cost after iteration 2614: 0.220070
# Cost after iteration 2615: 0.226951
# Cost after iteration 2616: 0.223552
# Cost after iteration 2617: 0.233626
# Cost after iteration 2618: 0.232598
# Cost after iteration 2619: 0.249407
# Cost after iteration 2620: 0.246182
# Cost after iteration 2621: 0.268934
# Cost after iteration 2622: 0.252969
# Cost after iteration 2623: 0.267459
# Cost after iteration 2624: 0.239936
# Cost after iteration 2625: 0.236208
# Cost after iteration 2626: 0.216231
# Cost after iteration 2627: 0.207054
# Cost after iteration 2628: 0.198600
# Cost after iteration 2629: 0.194787
# Cost after iteration 2630: 0.192337
# Cost after iteration 2631: 0.191289
# Cost after iteration 2632: 0.190540
# Cost after iteration 2633: 0.190160
# Cost after iteration 2634: 0.189834
# Cost after iteration 2635: 0.189630
# Cost after iteration 2636: 0.189440
# Cost after iteration 2637: 0.189300
# Cost after iteration 2638: 0.189167
# Cost after iteration 2639: 0.189057
# Cost after iteration 2640: 0.188952
# Cost after iteration 2641: 0.188860
# Cost after iteration 2642: 0.188771
# Cost after iteration 2643: 0.188689
# Cost after iteration 2644: 0.188611
# Cost after iteration 2645: 0.188538
# Cost after iteration 2646: 0.188467
# Cost after iteration 2647: 0.188400
# Cost after iteration 2648: 0.188335
# Cost after iteration 2649: 0.188274
# Cost after iteration 2650: 0.188214
# Cost after iteration 2651: 0.188157
# Cost after iteration 2652: 0.188101
# Cost after iteration 2653: 0.188048
# Cost after iteration 2654: 0.187996
# Cost after iteration 2655: 0.187947
# Cost after iteration 2656: 0.187899
# Cost after iteration 2657: 0.187853
# Cost after iteration 2658: 0.187809
# Cost after iteration 2659: 0.187767
# Cost after iteration 2660: 0.187726
# Cost after iteration 2661: 0.187687
# Cost after iteration 2662: 0.187650
# Cost after iteration 2663: 0.187616
# Cost after iteration 2664: 0.187584
# Cost after iteration 2665: 0.187556
# Cost after iteration 2666: 0.187529
# Cost after iteration 2667: 0.187510
# Cost after iteration 2668: 0.187492
# Cost after iteration 2669: 0.187487
# Cost after iteration 2670: 0.187483
# Cost after iteration 2671: 0.187502
# Cost after iteration 2672: 0.187522
# Cost after iteration 2673: 0.187588
# Cost after iteration 2674: 0.187653
# Cost after iteration 2675: 0.187812
# Cost after iteration 2676: 0.187963
# Cost after iteration 2677: 0.188325
# Cost after iteration 2678: 0.188650
# Cost after iteration 2679: 0.189479
# Cost after iteration 2680: 0.190178
# Cost after iteration 2681: 0.192172
# Cost after iteration 2682: 0.193755
# Cost after iteration 2683: 0.198888
# Cost after iteration 2684: 0.202540
# Cost after iteration 2685: 0.216098
# Cost after iteration 2686: 0.220589
# Cost after iteration 2687: 0.250969
# Cost after iteration 2688: 0.237508
# Cost after iteration 2689: 0.276131
# Cost after iteration 2690: 0.235766
# Cost after iteration 2691: 0.255951
# Cost after iteration 2692: 0.220698
# Cost after iteration 2693: 0.226156
# Cost after iteration 2694: 0.212581
# Cost after iteration 2695: 0.214885
# Cost after iteration 2696: 0.209081
# Cost after iteration 2697: 0.210846
# Cost after iteration 2698: 0.208001
# Cost after iteration 2699: 0.210075
# Cost after iteration 2700: 0.208451
# Cost after iteration 2701: 0.210995
# Cost after iteration 2702: 0.209499
# Cost after iteration 2703: 0.212142
# Cost after iteration 2704: 0.210045
# Cost after iteration 2705: 0.212058
# Cost after iteration 2706: 0.209037
# Cost after iteration 2707: 0.209666
# Cost after iteration 2708: 0.205958
# Cost after iteration 2709: 0.205044
# Cost after iteration 2710: 0.201392
# Cost after iteration 2711: 0.199679
# Cost after iteration 2712: 0.196827
# Cost after iteration 2713: 0.195251
# Cost after iteration 2714: 0.193408
# Cost after iteration 2715: 0.192334
# Cost after iteration 2716: 0.191262
# Cost after iteration 2717: 0.190615
# Cost after iteration 2718: 0.190006
# Cost after iteration 2719: 0.189625
# Cost after iteration 2720: 0.189266
# Cost after iteration 2721: 0.189035
# Cost after iteration 2722: 0.188811
# Cost after iteration 2723: 0.188662
# Cost after iteration 2724: 0.188511
# Cost after iteration 2725: 0.188409
# Cost after iteration 2726: 0.188301
# Cost after iteration 2727: 0.188228
# Cost after iteration 2728: 0.188145
# Cost after iteration 2729: 0.188092
# Cost after iteration 2730: 0.188027
# Cost after iteration 2731: 0.187988
# Cost after iteration 2732: 0.187937
# Cost after iteration 2733: 0.187911
# Cost after iteration 2734: 0.187872
# Cost after iteration 2735: 0.187860
# Cost after iteration 2736: 0.187832
# Cost after iteration 2737: 0.187837
# Cost after iteration 2738: 0.187822
# Cost after iteration 2739: 0.187851
# Cost after iteration 2740: 0.187853
# Cost after iteration 2741: 0.187917
# Cost after iteration 2742: 0.187945
# Cost after iteration 2743: 0.188066
# Cost after iteration 2744: 0.188132
# Cost after iteration 2745: 0.188352
# Cost after iteration 2746: 0.188480
# Cost after iteration 2747: 0.188879
# Cost after iteration 2748: 0.189114
# Cost after iteration 2749: 0.189855
# Cost after iteration 2750: 0.190286
# Cost after iteration 2751: 0.191722
# Cost after iteration 2752: 0.192535
# Cost after iteration 2753: 0.195479
# Cost after iteration 2754: 0.197066
# Cost after iteration 2755: 0.203401
# Cost after iteration 2756: 0.206121
# Cost after iteration 2757: 0.219443
# Cost after iteration 2758: 0.220127
# Cost after iteration 2759: 0.242925
# Cost after iteration 2760: 0.230607
# Cost after iteration 2761: 0.255020
# Cost after iteration 2762: 0.231293
# Cost after iteration 2763: 0.247609
# Cost after iteration 2764: 0.229147
# Cost after iteration 2765: 0.241170
# Cost after iteration 2766: 0.233262
# Cost after iteration 2767: 0.249326
# Cost after iteration 2768: 0.247624
# Cost after iteration 2769: 0.276856
# Cost after iteration 2770: 0.270008
# Cost after iteration 2771: 0.307184
# Cost after iteration 2772: 0.271390
# Cost after iteration 2773: 0.284499
# Cost after iteration 2774: 0.241051
# Cost after iteration 2775: 0.229683
# Cost after iteration 2776: 0.210085
# Cost after iteration 2777: 0.201497
# Cost after iteration 2778: 0.195626
# Cost after iteration 2779: 0.193372
# Cost after iteration 2780: 0.191846
# Cost after iteration 2781: 0.191180
# Cost after iteration 2782: 0.190636
# Cost after iteration 2783: 0.190332
# Cost after iteration 2784: 0.190064
# Cost after iteration 2785: 0.189878
# Cost after iteration 2786: 0.189710
# Cost after iteration 2787: 0.189574
# Cost after iteration 2788: 0.189447
# Cost after iteration 2789: 0.189336
# Cost after iteration 2790: 0.189231
# Cost after iteration 2791: 0.189134
# Cost after iteration 2792: 0.189042
# Cost after iteration 2793: 0.188955
# Cost after iteration 2794: 0.188871
# Cost after iteration 2795: 0.188792
# Cost after iteration 2796: 0.188715
# Cost after iteration 2797: 0.188642
# Cost after iteration 2798: 0.188571
# Cost after iteration 2799: 0.188503
# Cost after iteration 2800: 0.188437
# Cost after iteration 2801: 0.188374
# Cost after iteration 2802: 0.188312
# Cost after iteration 2803: 0.188253
# Cost after iteration 2804: 0.188195
# Cost after iteration 2805: 0.188139
# Cost after iteration 2806: 0.188085
# Cost after iteration 2807: 0.188033
# Cost after iteration 2808: 0.187982
# Cost after iteration 2809: 0.187933
# Cost after iteration 2810: 0.187885
# Cost after iteration 2811: 0.187839
# Cost after iteration 2812: 0.187794
# Cost after iteration 2813: 0.187750
# Cost after iteration 2814: 0.187708
# Cost after iteration 2815: 0.187667
# Cost after iteration 2816: 0.187627
# Cost after iteration 2817: 0.187589
# Cost after iteration 2818: 0.187551
# Cost after iteration 2819: 0.187516
# Cost after iteration 2820: 0.187481
# Cost after iteration 2821: 0.187448
# Cost after iteration 2822: 0.187417
# Cost after iteration 2823: 0.187389
# Cost after iteration 2824: 0.187362
# Cost after iteration 2825: 0.187339
# Cost after iteration 2826: 0.187319
# Cost after iteration 2827: 0.187307
# Cost after iteration 2828: 0.187298
# Cost after iteration 2829: 0.187304
# Cost after iteration 2830: 0.187317
# Cost after iteration 2831: 0.187362
# Cost after iteration 2832: 0.187417
# Cost after iteration 2833: 0.187544
# Cost after iteration 2834: 0.187689
# Cost after iteration 2835: 0.188009
# Cost after iteration 2836: 0.188346
# Cost after iteration 2837: 0.189148
# Cost after iteration 2838: 0.189931
# Cost after iteration 2839: 0.192037
# Cost after iteration 2840: 0.193957
# Cost after iteration 2841: 0.199902
# Cost after iteration 2842: 0.204702
# Cost after iteration 2843: 0.221856
# Cost after iteration 2844: 0.227090
# Cost after iteration 2845: 0.267199
# Cost after iteration 2846: 0.246285
# Cost after iteration 2847: 0.293396
# Cost after iteration 2848: 0.238783
# Cost after iteration 2849: 0.256687
# Cost after iteration 2850: 0.219462
# Cost after iteration 2851: 0.223147
# Cost after iteration 2852: 0.212330
# Cost after iteration 2853: 0.214424
# Cost after iteration 2854: 0.210251
# Cost after iteration 2855: 0.212776
# Cost after iteration 2856: 0.210967
# Cost after iteration 2857: 0.214579
# Cost after iteration 2858: 0.213321
# Cost after iteration 2859: 0.217879
# Cost after iteration 2860: 0.215860
# Cost after iteration 2861: 0.220422
# Cost after iteration 2862: 0.216678
# Cost after iteration 2863: 0.219542
# Cost after iteration 2864: 0.213954
# Cost after iteration 2865: 0.213711
# Cost after iteration 2866: 0.207534
# Cost after iteration 2867: 0.204888
# Cost after iteration 2868: 0.199963
# Cost after iteration 2869: 0.197256
# Cost after iteration 2870: 0.194366
# Cost after iteration 2871: 0.192732
# Cost after iteration 2872: 0.191329
# Cost after iteration 2873: 0.190514
# Cost after iteration 2874: 0.189856
# Cost after iteration 2875: 0.189451
# Cost after iteration 2876: 0.189118
# Cost after iteration 2877: 0.188899
# Cost after iteration 2878: 0.188708
# Cost after iteration 2879: 0.188572
# Cost after iteration 2880: 0.188448
# Cost after iteration 2881: 0.188353
# Cost after iteration 2882: 0.188262
# Cost after iteration 2883: 0.188189
# Cost after iteration 2884: 0.188117
# Cost after iteration 2885: 0.188057
# Cost after iteration 2886: 0.187997
# Cost after iteration 2887: 0.187946
# Cost after iteration 2888: 0.187893
# Cost after iteration 2889: 0.187849
# Cost after iteration 2890: 0.187803
# Cost after iteration 2891: 0.187764
# Cost after iteration 2892: 0.187724
# Cost after iteration 2893: 0.187690
# Cost after iteration 2894: 0.187655
# Cost after iteration 2895: 0.187627
# Cost after iteration 2896: 0.187597
# Cost after iteration 2897: 0.187576
# Cost after iteration 2898: 0.187553
# Cost after iteration 2899: 0.187542
# Cost after iteration 2900: 0.187527
# Cost after iteration 2901: 0.187531
# Cost after iteration 2902: 0.187528
# Cost after iteration 2903: 0.187555
# Cost after iteration 2904: 0.187572
# Cost after iteration 2905: 0.187639
# Cost after iteration 2906: 0.187688
# Cost after iteration 2907: 0.187827
# Cost after iteration 2908: 0.187933
# Cost after iteration 2909: 0.188209
# Cost after iteration 2910: 0.188418
# Cost after iteration 2911: 0.188975
# Cost after iteration 2912: 0.189380
# Cost after iteration 2913: 0.190546
# Cost after iteration 2914: 0.191355
# Cost after iteration 2915: 0.193941
# Cost after iteration 2916: 0.195646
# Cost after iteration 2917: 0.201736
# Cost after iteration 2918: 0.205125
# Cost after iteration 2919: 0.219393
# Cost after iteration 2920: 0.221456
# Cost after iteration 2921: 0.248636
# Cost after iteration 2922: 0.234101
# Cost after iteration 2923: 0.264169
# Cost after iteration 2924: 0.232932
# Cost after iteration 2925: 0.250263
# Cost after iteration 2926: 0.226196
# Cost after iteration 2927: 0.235784
# Cost after iteration 2928: 0.226360
# Cost after iteration 2929: 0.237247
# Cost after iteration 2930: 0.234956
# Cost after iteration 2931: 0.254405
# Cost after iteration 2932: 0.253783
# Cost after iteration 2933: 0.286991
# Cost after iteration 2934: 0.269930
# Cost after iteration 2935: 0.296965
# Cost after iteration 2936: 0.255180
# Cost after iteration 2937: 0.253908
# Cost after iteration 2938: 0.223668
# Cost after iteration 2939: 0.211639
# Cost after iteration 2940: 0.200498
# Cost after iteration 2941: 0.195722
# Cost after iteration 2942: 0.192857
# Cost after iteration 2943: 0.191704
# Cost after iteration 2944: 0.190907
# Cost after iteration 2945: 0.190504
# Cost after iteration 2946: 0.190169
# Cost after iteration 2947: 0.189953
# Cost after iteration 2948: 0.189760
# Cost after iteration 2949: 0.189611
# Cost after iteration 2950: 0.189474
# Cost after iteration 2951: 0.189356
# Cost after iteration 2952: 0.189245
# Cost after iteration 2953: 0.189145
# Cost after iteration 2954: 0.189050
# Cost after iteration 2955: 0.188961
# Cost after iteration 2956: 0.188876
# Cost after iteration 2957: 0.188795
# Cost after iteration 2958: 0.188717
# Cost after iteration 2959: 0.188643
# Cost after iteration 2960: 0.188572
# Cost after iteration 2961: 0.188503
# Cost after iteration 2962: 0.188437
# Cost after iteration 2963: 0.188373
# Cost after iteration 2964: 0.188311
# Cost after iteration 2965: 0.188251
# Cost after iteration 2966: 0.188194
# Cost after iteration 2967: 0.188138
# Cost after iteration 2968: 0.188084
# Cost after iteration 2969: 0.188032
# Cost after iteration 2970: 0.187981
# Cost after iteration 2971: 0.187932
# Cost after iteration 2972: 0.187884
# Cost after iteration 2973: 0.187838
# Cost after iteration 2974: 0.187793
# Cost after iteration 2975: 0.187750
# Cost after iteration 2976: 0.187708
# Cost after iteration 2977: 0.187668
# Cost after iteration 2978: 0.187629
# Cost after iteration 2979: 0.187591
# Cost after iteration 2980: 0.187555
# Cost after iteration 2981: 0.187521
# Cost after iteration 2982: 0.187488
# Cost after iteration 2983: 0.187458
# Cost after iteration 2984: 0.187430
# Cost after iteration 2985: 0.187406
# Cost after iteration 2986: 0.187384
# Cost after iteration 2987: 0.187369
# Cost after iteration 2988: 0.187358
# Cost after iteration 2989: 0.187361
# Cost after iteration 2990: 0.187369
# Cost after iteration 2991: 0.187405
# Cost after iteration 2992: 0.187451
# Cost after iteration 2993: 0.187559
# Cost after iteration 2994: 0.187679
# Cost after iteration 2995: 0.187949
# Cost after iteration 2996: 0.188228
# Cost after iteration 2997: 0.188887
# Cost after iteration 2998: 0.189521
# Cost after iteration 2999: 0.191196
# W1 = [[ 2.00482747 -1.6671195 ]
#  [ 2.20624522 -1.96417109]]
# b1 = [[-4.82886591]
#  [ 6.3169383 ]]
# W2 = [[-7.26183149  7.11613881]]
# b2 = [[-3.45130679]]

# %% [markdown]
# ##### __Expected Output__
# Note: the actual values can be different!
#
# ```Python
# Cost after iteration 0: 0.693148
# Cost after iteration 1: 0.693147
# Cost after iteration 2: 0.693147
# Cost after iteration 3: 0.693147
# Cost after iteration 4: 0.693147
# Cost after iteration 5: 0.693147
# ...
# Cost after iteration 2995: 0.209524
# Cost after iteration 2996: 0.208025
# Cost after iteration 2997: 0.210427
# Cost after iteration 2998: 0.208929
# Cost after iteration 2999: 0.211306
# W1 = [[ 2.14274251 -1.93155541]
#  [ 2.20268789 -2.1131799 ]]
# b1 = [[-4.83079243]
#  [ 6.2845223 ]]
# W2 = [[-7.21370685  7.0898022 ]]
# b2 = [[-3.48755239]]
# ```

# %%
# Note: 
# Actual values are not checked here in the unit tests (due to random initialization).
w3_unittest.test_nn_model(nn_model)
# Out:
#  All tests passed

# %% [markdown]
# The final model parameters can be used to find the boundary line and for making predictions.

# %% [markdown]
# <a name='ex08'></a>
# ### Exercise 8
#
# Computes probabilities using forward propagation, and make classification to 0/1 using 0.5 as the threshold.

# %%
# GRADED FUNCTION: predict

def predict(X, parameters):
    """
    Using the learned parameters, predicts a class for each example in X
    
    Arguments:
    parameters -- python dictionary containing your parameters 
    X -- input data of size (n_x, m)
    
    Returns
    predictions -- vector of predictions of our model (blue: 0 / red: 1)
    """
    
    ### START CODE HERE ### (≈ 2 lines of code)
    A2, cache = forward_propagation(X, parameters)
    predictions = A2 > 0.5
    ### END CODE HERE ###
    
    return predictions

# %%
X_pred = np.array([[2, 8, 2, 8], [2, 8, 8, 2]])
Y_pred = predict(X_pred, parameters)

print(f"Coordinates (in the columns):\n{X_pred}")
print(f"Predictions:\n{Y_pred}")
# Out:
# Coordinates (in the columns):
# [[2 8 2 8]
#  [2 8 8 2]]
# Predictions:
# [[ True  True False False]]

# %% [markdown]
# ##### __Expected Output__
#
# ```Python
# Coordinates (in the columns):
# [[2 8 2 8]
#  [2 8 8 2]]
# Predictions:
# [[ True  True False False]]
# ```

# %%
w3_unittest.test_predict(predict)
# Out:
#  All tests passed

# %% [markdown]
# Let's visualize the boundary line. Do not worry if you don't understand the function `plot_decision_boundary` line by line - it simply makes prediction for some points on the plane and plots them as a contour plot (just two colors - blue and red).

# %%
def plot_decision_boundary(predict, parameters, X, Y):
    # Define bounds of the domain.
    min1, max1 = X[0, :].min()-1, X[0, :].max()+1
    min2, max2 = X[1, :].min()-1, X[1, :].max()+1
    # Define the x and y scale.
    x1grid = np.arange(min1, max1, 0.1)
    x2grid = np.arange(min2, max2, 0.1)
    # Create all of the lines and rows of the grid.
    xx, yy = np.meshgrid(x1grid, x2grid)
    # Flatten each grid to a vector.
    r1, r2 = xx.flatten(), yy.flatten()
    r1, r2 = r1.reshape((1, len(r1))), r2.reshape((1, len(r2)))
    # Vertical stack vectors to create x1,x2 input for the model.
    grid = np.vstack((r1,r2))
    # Make predictions for the grid.
    predictions = predict(grid, parameters)
    # Reshape the predictions back into a grid.
    zz = predictions.reshape(xx.shape)
    # Plot the grid of x, y and z values as a surface.
    plt.contourf(xx, yy, zz, cmap=plt.cm.Spectral.reversed())
    plt.scatter(X[0, :], X[1, :], c=Y, cmap=colors.ListedColormap(['blue', 'red']));

# Plot the decision boundary.
plot_decision_boundary(predict, parameters, X, Y)
plt.title("Decision Boundary for hidden layer size " + str(n_h))
# Out:
# Text(0.5, 1.0, 'Decision Boundary for hidden layer size 2')

# %% [markdown]
# That's great, you can see that more complicated classification problems can be solved with two layer neural network!

# %% [markdown]
# <a name='4'></a>
# ## 4 - Optional: Other Dataset

# %% [markdown]
# Build a slightly different dataset:

# %%
n_samples = 2000
samples, labels = make_blobs(n_samples=n_samples, 
                             centers=([2.5, 3], [6.7, 7.9], [2.1, 7.9], [7.4, 2.8]), 
                             cluster_std=1.1,
                             random_state=0)
labels[(labels == 0)] = 0
labels[(labels == 1)] = 1
labels[(labels == 2) | (labels == 3)] = 1
X_2 = np.transpose(samples)
Y_2 = labels.reshape((1,n_samples))

plt.scatter(X_2[0, :], X_2[1, :], c=Y_2, cmap=colors.ListedColormap(['blue', 'red']));

# %% [markdown]
# Notice that when building your neural network, a number of the nodes in the hidden layer could be taken as a parameter. Try to change this parameter and investigate the results:

# %%
# parameters_2 = nn_model(X_2, Y_2, n_h=1, num_iterations=3000, learning_rate=1.2, print_cost=False)
parameters_2 = nn_model(X_2, Y_2, n_h=2, num_iterations=3000, learning_rate=1.2, print_cost=False)
# parameters_2 = nn_model(X_2, Y_2, n_h=15, num_iterations=3000, learning_rate=1.2, print_cost=False)

# This function will call predict function 
plot_decision_boundary(predict, parameters_2, X_2, Y_2)
plt.title("Decision Boundary")
# Out:
# Text(0.5, 1.0, 'Decision Boundary')

# %% [markdown]
# You can see that there are some misclassified points - real-world datasets are usually linearly inseparable, and there will be a small percentage of errors. More than that, you do not want to build a model that fits too closely, almost exactly to a particular set of data - it may fail to predict future observations. This problem is known as **overfitting**.

# %% [markdown]
# Congrats on finishing this programming assignment!
